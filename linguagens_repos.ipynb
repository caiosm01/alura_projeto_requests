# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# # Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"46416530716","type":"PushEvent","actor":{"id":73247344,"login":"gustot","display_login":"gustot","gravatar_id":"","url":"https://api.github.com/users/gustot","avatar_url":"https://avatars.githubusercontent.com/u/73247344?"},"repo":{"id":930437791,"name":"gustot/asdasd","url":"https://api.github.com/repos/gustot/asdasd"},"payload":{"repository_id":930437791,"push_id":22577041422,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"523f2fb76e59aecf97507ddde6a2967f64c16052","before":"955b367c37379731cdabc215de30cc37b919468c","commits":[{"sha":"523f2fb76e59aecf97507ddde6a2967f64c16052","author":{"email":"bayugustianto546@gmail.com","name":"gustot"},"message":"update","distinct":true,"url":"https://api.github.com/repos/gustot/asdasd/commits/523f2fb76e59aecf97507ddde6a2967f64c16052"}]},"public":true,"created_at":"2025-02-10T17:04:40Z"},{"id":"46416530708","type":"PushEvent","actor":{"id":80571763,"login":"nabilwafi","display_login":"nabilwafi","gravatar_id":"","url":"https://api.github.com/users/nabilwafi","avatar_url":"https://avatars.githubusercontent.com/u/80571763?"},"repo":{"id":908150577,"name":"nabilwafi/reforestation","url":"https://api.github.com/repos/nabilwafi/reforestation"},"payload":{"repository_id":908150577,"push_id":22577040191,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a6178cc5e590fa7734a1a473d3513f95a2f06a6b","before":"482f296faac2a121db2aaaf53aed99653a76311a","commits":[{"sha":"a6178cc5e590fa7734a1a473d3513f95a2f06a6b","author":{"email":"nabilwafi88@gmail.com","name":"nabilwafi"},"message":"What are you looking for?","distinct":true,"url":"https://api.github.com/repos/nabilwafi/reforestation/commits/a6178cc5e590fa7734a1a473d3513f95a2f06a6b"}]},"public":true,"created_at":"2025-02-10T17:04:40Z"},{"id":"46416530735","type":"IssueCommentEvent","actor":{"id":10086797,"login":"DominicOram","display_login":"DominicOram","gravatar_id":"","url":"https://api.github.com/users/DominicOram","avatar_url":"https://avatars.githubusercontent.com/u/10086797?"},"repo":{"id":530693238,"name":"DiamondLightSource/dodal","url":"https://api.github.com/repos/DiamondLightSource/dodal"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/DiamondLightSource/dodal/issues/1037","repository_url":"https://api.github.com/repos/DiamondLightSource/dodal","labels_url":"https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/labels{/name}","comments_url":"https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/comments","events_url":"https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/events","html_url":"https://github.com/DiamondLightSource/dodal/pull/1037","id":2830712919,"node_id":"PR_kwDOH6G8ds6KBZk3","number":1037,"title":"1034 pressure cell openseq type","user":{"login":"barnettwilliam","id":32113205,"node_id":"MDQ6VXNlcjMyMTEzMjA1","avatar_url":"https://avatars.githubusercontent.com/u/32113205?v=4","gravatar_id":"","url":"https://api.github.com/users/barnettwilliam","html_url":"https://github.com/barnettwilliam","followers_url":"https://api.github.com/users/barnettwilliam/followers","following_url":"https://api.github.com/users/barnettwilliam/following{/other_user}","gists_url":"https://api.github.com/users/barnettwilliam/gists{/gist_id}","starred_url":"https://api.github.com/users/barnettwilliam/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/barnettwilliam/subscriptions","organizations_url":"https://api.github.com/users/barnettwilliam/orgs","repos_url":"https://api.github.com/users/barnettwilliam/repos","events_url":"https://api.github.com/users/barnettwilliam/events{/privacy}","received_events_url":"https://api.github.com/users/barnettwilliam/received_events","type":"User","user_view_type":"public","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":3,"created_at":"2025-02-04T16:13:27Z","updated_at":"2025-02-10T17:04:40Z","closed_at":null,"author_association": ...

# %%
r.json()
# Out:
# [{'id': '46416530716',
#   'type': 'PushEvent',
#   'actor': {'id': 73247344,
#    'login': 'gustot',
#    'display_login': 'gustot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gustot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73247344?'},
#   'repo': {'id': 930437791,
#    'name': 'gustot/asdasd',
#    'url': 'https://api.github.com/repos/gustot/asdasd'},
#   'payload': {'repository_id': 930437791,
#    'push_id': 22577041422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '523f2fb76e59aecf97507ddde6a2967f64c16052',
#    'before': '955b367c37379731cdabc215de30cc37b919468c',
#    'commits': [{'sha': '523f2fb76e59aecf97507ddde6a2967f64c16052',
#      'author': {'email': 'bayugustianto546@gmail.com', 'name': 'gustot'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gustot/asdasd/commits/523f2fb76e59aecf97507ddde6a2967f64c16052'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530708',
#   'type': 'PushEvent',
#   'actor': {'id': 80571763,
#    'login': 'nabilwafi',
#    'display_login': 'nabilwafi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nabilwafi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80571763?'},
#   'repo': {'id': 908150577,
#    'name': 'nabilwafi/reforestation',
#    'url': 'https://api.github.com/repos/nabilwafi/reforestation'},
#   'payload': {'repository_id': 908150577,
#    'push_id': 22577040191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a6178cc5e590fa7734a1a473d3513f95a2f06a6b',
#    'before': '482f296faac2a121db2aaaf53aed99653a76311a',
#    'commits': [{'sha': 'a6178cc5e590fa7734a1a473d3513f95a2f06a6b',
#      'author': {'email': 'nabilwafi88@gmail.com', 'name': 'nabilwafi'},
#      'message': 'What are you looking for?',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nabilwafi/reforestation/commits/a6178cc5e590fa7734a1a473d3513f95a2f06a6b'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530735',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 10086797,
#    'login': 'DominicOram',
#    'display_login': 'DominicOram',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DominicOram',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10086797?'},
#   'repo': {'id': 530693238,
#    'name': 'DiamondLightSource/dodal',
#    'url': 'https://api.github.com/repos/DiamondLightSource/dodal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037',
#     'repository_url': 'https://api.github.com/repos/DiamondLightSource/dodal',
#     'labels_url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/comments',
#     'events_url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/events',
#     'html_url': 'https://github.com/DiamondLightSource/dodal/pull/1037',
#     'id': 2830712919,
#     'node_id': 'PR_kwDOH6G8ds6KBZk3',
#     'number': 1037,
#     'title': '1034 pressure cell openseq type',
#     'user': {'login': 'barnettwilliam',
#      'id': 32113205,
#      'node_id': 'MDQ6VXNlcjMyMTEzMjA1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/32113205?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/barnettwilliam',
#      'html_url': 'https://github.com/barnettwilliam',
#      'followers_url': 'https://api.github.com/users/barnettwilliam/followers',
#      'following_url': 'https://api.github.com/users/barnettwilliam/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/barnettwilliam/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/barnettwilliam/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/barnettwilliam/subscriptions',
#      'organizations_url': 'https://api.github.com/users/barnettwilliam/orgs',
#      'repos_url': 'https://api.github.com/users/barnettwilliam/repos',
#      'events_url': 'https://api.github.com/users/barnettwilliam/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/barnettwilliam/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2025-02-04T16:13:27Z',
#     'updated_at': '2025-02-10T17:04:40Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/DiamondLightSource/dodal/pulls/1037',
#      'html_url': 'https://github.com/DiamondLightSource/dodal/pull/1037',
#      'diff_url': 'https://github.com/DiamondLightSource/dodal/pull/1037.diff',
#      'patch_url': 'https://github.com/DiamondLightSource/dodal/pull/1037.patch',
#      'merged_at': None},
#     'body': 'Fixes #1034\r\n\r\n### Instructions to reviewer on how to test:\r\n1. `dodal connect p38`\r\n2. Confirm the pressure cell is in the list of connected devices\r\n\r\n### Checks for reviewer\r\n- [ ] Would the PR title make sense to a scientist on a set of release notes\r\n- [ ] If a new device has been added does it follow the [standards](https://diamondlightsource.github.io/dodal/main/reference/device-standards.html)\r\n- [ ] If changing the API for a pre-existing device, ensure that any beamlines using this device have updated their Bluesky plans accordingly\r\n- [ ] Have the connection tests for the relevant beamline(s) been run via `dodal connect ${BEAMLINE}`\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/comments/2648691491',
#     'html_url': 'https://github.com/DiamondLightSource/dodal/pull/1037#issuecomment-2648691491',
#     'issue_url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/1037',
#     'id': 2648691491,
#     'node_id': 'IC_kwDOH6G8ds6d39Mj',
#     'user': {'login': 'DominicOram',
#      'id': 10086797,
#      'node_id': 'MDQ6VXNlcjEwMDg2Nzk3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10086797?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DominicOram',
#      'html_url': 'https://github.com/DominicOram',
#      'followers_url': 'https://api.github.com/users/DominicOram/followers',
#      'following_url': 'https://api.github.com/users/DominicOram/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DominicOram/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DominicOram/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DominicOram/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DominicOram/orgs',
#      'repos_url': 'https://api.github.com/users/DominicOram/repos',
#      'events_url': 'https://api.github.com/users/DominicOram/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DominicOram/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-02-10T17:04:38Z',
#     'updated_at': '2025-02-10T17:04:38Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "> It's the intention of the set_valve() method of a PressureJumpCell's all_valves_control attribute (AllValvesControl) to handle the opening/closing by setting OPEN_SEQ e.g. cell.all_valves_control.set_valve( valve-number, request) from a FastValveControlRequest or ValveControlRequest to simplify things for the user.\r\n\r\nThe user does not have access to `set_value` only to the bluesky verb of `set`. \r\n\r\nI also think the idea of being able to do `yield from bps.set(cell.all_valves_control, AllValvesControlState(valve_1=ValveControlRequest.OPEN, valve_5=FastValveControlRequest.CLOSE)` may need changing based on https://github.com/DiamondLightSource/dodal/issues/1031. I will add a note there.\r\n\r\nI will make an issue. Are they being used somewhere in https://github.com/DiamondLightSource/i10-bluesky?\r\n\r\n",
#     'reactions': {'url': 'https://api.github.com/repos/DiamondLightSource/dodal/issues/comments/2648691491/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z',
#   'org': {'id': 1233618,
#    'login': 'DiamondLightSource',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DiamondLightSource',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1233618?'}},
#  {'id': '46416530741',
#   'type': 'WatchEvent',
#   'actor': {'id': 187223512,
#    'login': 'Ilman-Tech',
#    'display_login': 'Ilman-Tech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ilman-Tech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/187223512?'},
#   'repo': {'id': 600264273,
#    'name': 'kat9897/Virtual-Valentine-Card',
#    'url': 'https://api.github.com/repos/kat9897/Virtual-Valentine-Card'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530724',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 128663333,
#    'login': 'Arminh388',
#    'display_login': 'Arminh388',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arminh388',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?'},
#   'repo': {'id': 832342204,
#    'name': 'Arminh388/Generative-Photo-Reconstruction',
#    'url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction'},
#   'payload': {'action': 'reopened',
#    'number': 8,
#    'pull_request': {'url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8',
#     'id': 2326652942,
#     'node_id': 'PR_kwDOMZyIvM6KregO',
#     'html_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction/pull/8',
#     'diff_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction/pull/8.diff',
#     'patch_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction/pull/8.patch',
#     'issue_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/8',
#     'number': 8,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update hybrid_gan.py',
#     'user': {'login': 'Arminh388',
#      'id': 128663333,
#      'node_id': 'U_kgDOB6s_JQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Arminh388',
#      'html_url': 'https://github.com/Arminh388',
#      'followers_url': 'https://api.github.com/users/Arminh388/followers',
#      'following_url': 'https://api.github.com/users/Arminh388/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Arminh388/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Arminh388/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Arminh388/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Arminh388/orgs',
#      'repos_url': 'https://api.github.com/users/Arminh388/repos',
#      'events_url': 'https://api.github.com/users/Arminh388/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Arminh388/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'See READ.ME.',
#     'created_at': '2025-02-10T17:02:26Z',
#     'updated_at': '2025-02-10T17:04:39Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '8a305948f77e69b8ae8b13420d8a7be40969b01d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8/commits',
#     'review_comments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8/comments',
#     'review_comment_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/8/comments',
#     'statuses_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/statuses/f3de39a07c369a6fa8029e0ccfd1191ca85e9237',
#     'head': {'label': 'Arminh388:Arminh388-1-hybrid',
#      'ref': 'Arminh388-1-hybrid',
#      'sha': 'f3de39a07c369a6fa8029e0ccfd1191ca85e9237',
#      'user': {'login': 'Arminh388',
#       'id': 128663333,
#       'node_id': 'U_kgDOB6s_JQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Arminh388',
#       'html_url': 'https://github.com/Arminh388',
#       'followers_url': 'https://api.github.com/users/Arminh388/followers',
#       'following_url': 'https://api.github.com/users/Arminh388/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Arminh388/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Arminh388/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Arminh388/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Arminh388/orgs',
#       'repos_url': 'https://api.github.com/users/Arminh388/repos',
#       'events_url': 'https://api.github.com/users/Arminh388/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Arminh388/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 832342204,
#       'node_id': 'R_kgDOMZyIvA',
#       'name': 'Generative-Photo-Reconstruction',
#       'full_name': 'Arminh388/Generative-Photo-Reconstruction',
#       'private': False,
#       'owner': {'login': 'Arminh388',
#        'id': 128663333,
#        'node_id': 'U_kgDOB6s_JQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Arminh388',
#        'html_url': 'https://github.com/Arminh388',
#        'followers_url': 'https://api.github.com/users/Arminh388/followers',
#        'following_url': 'https://api.github.com/users/Arminh388/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Arminh388/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Arminh388/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Arminh388/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Arminh388/orgs',
#        'repos_url': 'https://api.github.com/users/Arminh388/repos',
#        'events_url': 'https://api.github.com/users/Arminh388/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Arminh388/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction',
#       'description': 'QMIND 2024-25',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction',
#       'forks_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/forks',
#       'keys_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/teams',
#       'hooks_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/events',
#       'assignees_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/tags',
#       'blobs_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/languages',
#       'stargazers_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/subscription',
#       'commits_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/merges',
#       'archive_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/downloads',
#       'issues_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/deployments',
#       'created_at': '2024-07-22T20:35:43Z',
#       'updated_at': '2025-01-02T07:52:45Z',
#       'pushed_at': '2025-02-10T17:02:07Z',
#       'git_url': 'git://github.com/Arminh388/Generative-Photo-Reconstruction.git',
#       'ssh_url': 'git@github.com:Arminh388/Generative-Photo-Reconstruction.git',
#       'clone_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction.git',
#       'svn_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction',
#       'homepage': None,
#       'size': 3677,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'Arminh388:main',
#      'ref': 'main',
#      'sha': '7b4dda9c43ce8fae98683ba21237d745444b95e0',
#      'user': {'login': 'Arminh388',
#       'id': 128663333,
#       'node_id': 'U_kgDOB6s_JQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Arminh388',
#       'html_url': 'https://github.com/Arminh388',
#       'followers_url': 'https://api.github.com/users/Arminh388/followers',
#       'following_url': 'https://api.github.com/users/Arminh388/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Arminh388/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Arminh388/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Arminh388/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Arminh388/orgs',
#       'repos_url': 'https://api.github.com/users/Arminh388/repos',
#       'events_url': 'https://api.github.com/users/Arminh388/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Arminh388/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 832342204,
#       'node_id': 'R_kgDOMZyIvA',
#       'name': 'Generative-Photo-Reconstruction',
#       'full_name': 'Arminh388/Generative-Photo-Reconstruction',
#       'private': False,
#       'owner': {'login': 'Arminh388',
#        'id': 128663333,
#        'node_id': 'U_kgDOB6s_JQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/128663333?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Arminh388',
#        'html_url': 'https://github.com/Arminh388',
#        'followers_url': 'https://api.github.com/users/Arminh388/followers',
#        'following_url': 'https://api.github.com/users/Arminh388/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Arminh388/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Arminh388/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Arminh388/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Arminh388/orgs',
#        'repos_url': 'https://api.github.com/users/Arminh388/repos',
#        'events_url': 'https://api.github.com/users/Arminh388/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Arminh388/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction',
#       'description': 'QMIND 2024-25',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction',
#       'forks_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/forks',
#       'keys_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/teams',
#       'hooks_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/events',
#       'assignees_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/tags',
#       'blobs_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/languages',
#       'stargazers_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/subscription',
#       'commits_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/merges',
#       'archive_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/downloads',
#       'issues_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/deployments',
#       'created_at': '2024-07-22T20:35:43Z',
#       'updated_at': '2025-01-02T07:52:45Z',
#       'pushed_at': '2025-02-10T17:02:07Z',
#       'git_url': 'git://github.com/Arminh388/Generative-Photo-Reconstruction.git',
#       'ssh_url': 'git@github.com:Arminh388/Generative-Photo-Reconstruction.git',
#       'clone_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction.git',
#       'svn_url': 'https://github.com/Arminh388/Generative-Photo-Reconstruction',
#       'homepage': None,
#       'size': 3677,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8'},
#      'html': {'href': 'https://github.com/Arminh388/Generative-Photo-Reconstruction/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Arminh388/Generative-Photo-Reconstruction/statuses/f3de39a07c369a6fa8029e0ccfd1191ca85e9237'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 194,
#     'deletions': 172,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530453',
#   'type': 'PushEvent',
#   'actor': {'id': 280181,
#    'login': 'tomponline',
#    'display_login': 'tomponline',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tomponline',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/280181?'},
#   'repo': {'id': 181285309,
#    'name': 'tomponline/lxd',
#    'url': 'https://api.github.com/repos/tomponline/lxd'},
#   'payload': {'repository_id': 181285309,
#    'push_id': 22577039876,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/tp-ovn-ptr',
#    'head': '3bce8cc2b9be4c676357d5e21bfd9c129ba8bbf0',
#    'before': '800e09695e00fa5be6673aecc71c116d0e02f489',
#    'commits': [{'sha': '3bce8cc2b9be4c676357d5e21bfd9c129ba8bbf0',
#      'author': {'email': 'thomas.parrott@canonical.com',
#       'name': 'Thomas Parrott'},
#      'message': 'test: Add tests for ovn DNS\n\nSigned-off-by: Thomas Parrott <thomas.parrott@canonical.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tomponline/lxd/commits/3bce8cc2b9be4c676357d5e21bfd9c129ba8bbf0'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530701',
#   'type': 'PushEvent',
#   'actor': {'id': 173932847,
#    'login': 'Webtinz',
#    'display_login': 'Webtinz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Webtinz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173932847?'},
#   'repo': {'id': 895460318,
#    'name': 'Webtinz/Medtinz',
#    'url': 'https://api.github.com/repos/Webtinz/Medtinz'},
#   'payload': {'repository_id': 895460318,
#    'push_id': 22577039209,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/semia_backend',
#    'head': 'c93d9a4176dc65ca3daa6beb672bdaf8b3bb03d7',
#    'before': 'e4cffdb4bb92dc1573647003fa5b12db52f1f2d9',
#    'commits': [{'sha': 'c93d9a4176dc65ca3daa6beb672bdaf8b3bb03d7',
#      'author': {'email': 'ittiqdev3@outlook.com', 'name': 'Webtinz'},
#      'message': 'myfirstserver',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Webtinz/Medtinz/commits/c93d9a4176dc65ca3daa6beb672bdaf8b3bb03d7'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530672',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 871114450,
#    'name': 'the-standard/filtered-apy-data',
#    'url': 'https://api.github.com/repos/the-standard/filtered-apy-data'},
#   'payload': {'repository_id': 871114450,
#    'push_id': 22577040236,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ae1849f466c2311eb7b2b55dbf1f992d747e338f',
#    'before': 'efcccb26c7c6d0c6894cb15db6b1527a97da7c48',
#    'commits': [{'sha': 'ae1849f466c2311eb7b2b55dbf1f992d747e338f',
#      'author': {'email': 'actions@github.com', 'name': 'GitHub Action'},
#      'message': 'Update APY data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/the-standard/filtered-apy-data/commits/ae1849f466c2311eb7b2b55dbf1f992d747e338f'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z',
#   'org': {'id': 84790875,
#    'login': 'the-standard',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/the-standard',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84790875?'}},
#  {'id': '46416530646',
#   'type': 'PushEvent',
#   'actor': {'id': 143397992,
#    'login': 'Jujez04',
#    'display_login': 'Jujez04',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jujez04',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/143397992?'},
#   'repo': {'id': 911591848,
#    'name': 'EnryBarto/OOP24-balatro-lt',
#    'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt'},
#   'payload': {'repository_id': 911591848,
#    'push_id': 22577039124,
#    'size': 10,
#    'distinct_size': 4,
#    'ref': 'refs/heads/feature/combination',
#    'head': '10c06422e413b724104f595c315e2b6636d51864',
#    'before': '1ebbe34e1260ca380536535ff486758a7bdf2918',
#    'commits': [{'sha': 'b83cb6997eceaf2c77c2f3df8f4fa49883c1d9bc',
#      'author': {'email': 'nicolas.tazzieri@studio.unibo.it',
#       'name': 'Nicolas Tazzieri'},
#      'message': 'feat: modified BlindOver GUI',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/b83cb6997eceaf2c77c2f3df8f4fa49883c1d9bc'},
#     {'sha': '59f84069fd96d3efef55fd7cc77693410ab19a21',
#      'author': {'email': 'enrico.bartocetti@studio.unibo.it',
#       'name': 'Enrico Bartocetti'},
#      'message': 'feat: Ordering cards when staged',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/59f84069fd96d3efef55fd7cc77693410ab19a21'},
#     {'sha': '7b7f67f168b6f9c87843f56f3fbef3f8a08a4704',
#      'author': {'email': 'nicolas.tazzieri@studio.unibo.it',
#       'name': 'Nicolas Tazzieri'},
#      'message': 'refactor: BlindOver',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/7b7f67f168b6f9c87843f56f3fbef3f8a08a4704'},
#     {'sha': '6fdc042d8af0908cb136c346be4429091d3d749a',
#      'author': {'email': 'nicolas.tazzieri@studio.unibo.it',
#       'name': 'Nicolas Tazzieri'},
#      'message': "Merge branch 'develop/sortHand'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/6fdc042d8af0908cb136c346be4429091d3d749a'},
#     {'sha': '129ace7ec8ae28aa0031c01f2536f2a93b772f11',
#      'author': {'email': 'nicolas.tazzieri@studio.unibo.it',
#       'name': 'Nicolas Tazzieri'},
#      'message': 'fix: checkstyle and pmd issues',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/129ace7ec8ae28aa0031c01f2536f2a93b772f11'},
#     {'sha': 'cc310f9b28c57e158a4adcd1b907e27af9822959',
#      'author': {'email': 'justin.carideo@studio.unibo.it',
#       'name': 'Justin Carideo'},
#      'message': "Merge branch 'feature/combination'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/cc310f9b28c57e158a4adcd1b907e27af9822959'},
#     {'sha': 'ef8ca06a4872bd713b7b2ed6c6ee55a62265db03',
#      'author': {'email': 'justin.carideo@studio.unibo.it',
#       'name': 'Justin Carideo'},
#      'message': 'add: javadoc in CombinationTable',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/ef8ca06a4872bd713b7b2ed6c6ee55a62265db03'},
#     {'sha': '2182f47b33734837c3a6f67d71239d054f15d9a5',
#      'author': {'email': 'justin.carideo@studio.unibo.it',
#       'name': 'Justin Carideo'},
#      'message': "Merge branch 'feature/combination'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/2182f47b33734837c3a6f67d71239d054f15d9a5'},
#     {'sha': '8f9c335b93f3b84e77cea8576a42dc4a070fa60d',
#      'author': {'email': 'justin.carideo@studio.unibo.it',
#       'name': 'Justin Carideo'},
#      'message': 'add: CombinationTable in GUI as a second window',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/8f9c335b93f3b84e77cea8576a42dc4a070fa60d'},
#     {'sha': '10c06422e413b724104f595c315e2b6636d51864',
#      'author': {'email': 'justin.carideo@studio.unibo.it',
#       'name': 'Justin Carideo'},
#      'message': 'fix&add: about the previous commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnryBarto/OOP24-balatro-lt/commits/10c06422e413b724104f595c315e2b6636d51864'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530652',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 400095,
#    'login': 'gunterze',
#    'display_login': 'gunterze',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gunterze',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/400095?'},
#   'repo': {'id': 39013067,
#    'name': 'dcm4che/dcm4chee-arc-light',
#    'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353',
#     'repository_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light',
#     'labels_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353/comments',
#     'events_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353/events',
#     'html_url': 'https://github.com/dcm4che/dcm4chee-arc-light/issues/4353',
#     'id': 2083425774,
#     'node_id': 'I_kwDOAlNKy858Lo3u',
#     'number': 4353,
#     'title': 'Re-import Study RS : Duplicate location record created with status `ORPHANED` on re-importing a study',
#     'user': {'login': 'vrindanayak',
#      'id': 15785031,
#      'node_id': 'MDQ6VXNlcjE1Nzg1MDMx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/15785031?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vrindanayak',
#      'html_url': 'https://github.com/vrindanayak',
#      'followers_url': 'https://api.github.com/users/vrindanayak/followers',
#      'following_url': 'https://api.github.com/users/vrindanayak/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vrindanayak/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vrindanayak/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vrindanayak/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vrindanayak/orgs',
#      'repos_url': 'https://api.github.com/users/vrindanayak/repos',
#      'events_url': 'https://api.github.com/users/vrindanayak/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vrindanayak/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 235692356,
#       'node_id': 'MDU6TGFiZWwyMzU2OTIzNTY=',
#       'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'vrindanayak',
#      'id': 15785031,
#      'node_id': 'MDQ6VXNlcjE1Nzg1MDMx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/15785031?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vrindanayak',
#      'html_url': 'https://github.com/vrindanayak',
#      'followers_url': 'https://api.github.com/users/vrindanayak/followers',
#      'following_url': 'https://api.github.com/users/vrindanayak/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vrindanayak/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vrindanayak/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vrindanayak/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vrindanayak/orgs',
#      'repos_url': 'https://api.github.com/users/vrindanayak/repos',
#      'events_url': 'https://api.github.com/users/vrindanayak/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vrindanayak/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'vrindanayak',
#       'id': 15785031,
#       'node_id': 'MDQ6VXNlcjE1Nzg1MDMx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/15785031?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vrindanayak',
#       'html_url': 'https://github.com/vrindanayak',
#       'followers_url': 'https://api.github.com/users/vrindanayak/followers',
#       'following_url': 'https://api.github.com/users/vrindanayak/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vrindanayak/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vrindanayak/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vrindanayak/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vrindanayak/orgs',
#       'repos_url': 'https://api.github.com/users/vrindanayak/repos',
#       'events_url': 'https://api.github.com/users/vrindanayak/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vrindanayak/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/milestones/85',
#      'html_url': 'https://github.com/dcm4che/dcm4chee-arc-light/milestone/85',
#      'labels_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/milestones/85/labels',
#      'id': 10338655,
#      'node_id': 'MI_kwDOAlNKy84AncFf',
#      'number': 85,
#      'title': '5.32.0',
#      'description': '',
#      'creator': {'login': 'gunterze',
#       'id': 400095,
#       'node_id': 'MDQ6VXNlcjQwMDA5NQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/400095?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gunterze',
#       'html_url': 'https://github.com/gunterze',
#       'followers_url': 'https://api.github.com/users/gunterze/followers',
#       'following_url': 'https://api.github.com/users/gunterze/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gunterze/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gunterze/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gunterze/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gunterze/orgs',
#       'repos_url': 'https://api.github.com/users/gunterze/repos',
#       'events_url': 'https://api.github.com/users/gunterze/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gunterze/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'open_issues': 1,
#      'closed_issues': 136,
#      'state': 'closed',
#      'created_at': '2023-12-21T14:18:56Z',
#      'updated_at': '2025-02-10T17:03:41Z',
#      'due_on': None,
#      'closed_at': '2024-04-22T11:11:24Z'},
#     'comments': 1,
#     'created_at': '2024-01-16T09:25:41Z',
#     'updated_at': '2025-02-10T17:04:40Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'body': 'Invoke [Re-import Study](https://petstore.swagger.io/index.html?url=https://dcm4che.github.io/dcm4chee-arc-light/swagger/openapi.json#/IOCM-RS/ReimportStudy) on an existing study in archive\r\n\r\nArchive log\r\n```\r\n10:23:38,205 INFO  [org.dcm4chee.arc.stow.ImportStorageRS] (default task-1) Process POST /dcm4chee-arc/aets/DCM4CHEE/rs/studies/1.2.392.200036.9125.0.199402091242.1/reimport?sourceOfPreviousValues=Default%20Archive%20Coercion&updatePolicy=OVERWRITE&reasonForModification=CORRECT&00100021=JMS&00100030=19651212 from null@127.0.0.1\r\n10:23:38,233 INFO  [org.dcm4chee.arc.delete.impl.DeletionServiceImpl] (default task-1) Start deleting Study[pk=2166, uid=1.2.392.200036.9125.0.199402091242.1, id=*] from database\r\n10:23:38,405 INFO  [org.dcm4chee.arc.delete.impl.DeletionServiceImpl] (default task-1) Successfully delete Study[pk=2166, uid=1.2.392.200036.9125.0.199402091242.1, id=*] from database\r\n10:23:38,467 INFO  [org.dcm4chee.arc.patient.impl.PatientServiceEJB] (default task-1) 127.0.0.1: Create Patient[pk=2536, id=[FUJI00007^^^JMS], name=ITO^TOSHIAKI]\r\n10:23:38,475 INFO  [org.dcm4chee.arc.store.impl.StoreServiceEJB] (default task-1) 127.0.0.1@127.0.0.1->DCM4CHEE: Create Study[pk=2167, uid=1.2.392.200036.9125.0.199402091242.1, id=*]\r\n10:23:38,478 INFO  [org.dcm4chee.arc.store.impl.StoreServiceEJB] (default task-1) 127.0.0.1@127.0.0.1->DCM4CHEE: Create Series[pk=3339, uid=1.2.392.200036.9125.0.199402091242.1, no=null, mod=CR]\r\n10:23:38,482 INFO  [org.dcm4chee.arc.store.impl.StoreServiceEJB] (default task-1) 127.0.0.1@127.0.0.1->DCM4CHEE: Create Instance[pk=57422, uid=1.2.392.200036.9125.0.19950720105640, class=1.2.840.10008.5.1.4.1.1.1, no=1]\r\n10:23:38,590 INFO  [org.dcm4chee.arc.store.impl.StoreServiceEJB] (default task-1) 127.0.0.1@127.0.0.1->DCM4CHEE: Create Location[pk=58789, systemID=fs1, path=2024/01/16/27B3738F/27B3738F/51F31B5C, tsuid=1.2.840.10008.1.2, size=7533874, status=ORPHANED, objectType=DICOM_FILE]\r\n10:23:38,617 INFO  [org.dcm4chee.arc.store.impl.StoreServiceImpl] (default task-1) 127.0.0.1@127.0.0.1->DCM4CHEE: Updated DB in 203 ms\r\n10:23:38,629 INFO  [org.dcm4chee.arc.patient.impl.PatientServiceEJB] (default task-1) No duplicate record with equal Patient ID found Patient[pk=2536, id=[FUJI00007^^^JMS], name=ITO^TOSHIAKI]\r\n```\r\n\r\nResulting location records in DB :\r\n```\r\n58788,2024-01-16 10:23:04.432000,9CAC124E4175C33F860C0EC6AD2A6E57,0,0,7533874,10,fs1,2024/01/16/27B3738F/27B3738F/51F31B5C,1.2.840.10008.1.2,,\r\n58789,2024-01-16 10:23:38.588000,9CAC124E4175C33F860C0EC6AD2A6E57,0,0,7533874,10,fs1,2024/01/16/27B3738F/27B3738F/51F31B5C,1.2.840.10008.1.2,168,57422\r\n```',
#     'reactions': {'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/4353/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'reopened'},
#    'comment': {'url': 'https://api.github.com/repos/dcm4che/dcm4chee-arc-light/issues/comments/2648691468',
# ...
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 3986,
#     'deletions': 2276,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z',
#   'org': {'id': 28379899,
#    'login': 'mate-academy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mate-academy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28379899?'}},
#  {'id': '46416530628',
#   'type': 'PublicEvent',
#   'actor': {'id': 3766324,
#    'login': 'Iblouse',
#    'display_login': 'Iblouse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Iblouse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3766324?'},
#   'repo': {'id': 930407539,
#    'name': 'Iblouse/Mock-Interview',
#    'url': 'https://api.github.com/repos/Iblouse/Mock-Interview'},
#   'payload': {},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530617',
#   'type': 'PushEvent',
#   'actor': {'id': 137032093,
#    'login': 'MohammadKobirShah',
#    'display_login': 'MohammadKobirShah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MohammadKobirShah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137032093?'},
#   'repo': {'id': 837462068,
#    'name': 'MohammadKobirShah/KobirIPTV',
#    'url': 'https://api.github.com/repos/MohammadKobirShah/KobirIPTV'},
#   'payload': {'repository_id': 837462068,
#    'push_id': 22577040900,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2877f47655fb78424ce02dd3318c6de357a1f461',
#    'before': '36f2278b5f712699afbcfb142e7cfae07e54a899',
#    'commits': [{'sha': '2877f47655fb78424ce02dd3318c6de357a1f461',
#      'author': {'email': '137032093+MohammadKobirShah@users.noreply.github.com',
#       'name': 'MohammadKobirShah'},
#      'message': 'Update KobirIPTV.m3u',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MohammadKobirShah/KobirIPTV/commits/2877f47655fb78424ce02dd3318c6de357a1f461'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530619',
#   'type': 'PushEvent',
#   'actor': {'id': 123503901,
#    'login': 'Kenshi2727',
#    'display_login': 'Kenshi2727',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kenshi2727',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123503901?'},
#   'repo': {'id': 917311738,
#    'name': 'Kenshi2727/Kenshi-Resumes-AI-Powered',
#    'url': 'https://api.github.com/repos/Kenshi2727/Kenshi-Resumes-AI-Powered'},
#   'payload': {'repository_id': 917311738,
#    'push_id': 22577040617,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '84eadedc3a1bcbac18f1ed5898b77615a8c145d0',
#    'before': '20b18c42eac7cedbfd466b8f048b82d4f6af20fd',
#    'commits': [{'sha': '84eadedc3a1bcbac18f1ed5898b77615a8c145d0',
#      'author': {'email': 'abhishekmathurofficial@gmail.com',
#       'name': 'Abhishek Mathur'},
#      'message': 'changed auth settings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Kenshi2727/Kenshi-Resumes-AI-Powered/commits/84eadedc3a1bcbac18f1ed5898b77615a8c145d0'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530634',
#   'type': 'WatchEvent',
#   'actor': {'id': 104380885,
#    'login': 'user0-07161',
#    'display_login': 'user0-07161',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/user0-07161',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104380885?'},
#   'repo': {'id': 23101042,
#    'name': 'pocketbook/Platform_MX6',
#    'url': 'https://api.github.com/repos/pocketbook/Platform_MX6'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530561',
#   'type': 'PushEvent',
#   'actor': {'id': 125030768,
#    'login': 'FrozenQxc',
#    'display_login': 'FrozenQxc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FrozenQxc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125030768?'},
#   'repo': {'id': 930454049,
#    'name': 'Samurai-Club/Test',
#    'url': 'https://api.github.com/repos/Samurai-Club/Test'},
#   'payload': {'repository_id': 930454049,
#    'push_id': 22577039795,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9747b3d51c4ee182352d7efa5ca0503ec291686c',
#    'before': '69bf3300fefbbf2ffbb8a7b234958f99aba8fe12',
#    'commits': [{'sha': '702b21250ae006f457c9a2e6d39b03c3b8a43db0',
#      'author': {'email': '125030768+FrozenQxc@users.noreply.github.com',
#       'name': 'WUKYGE'},
#      'message': 'test',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Samurai-Club/Test/commits/702b21250ae006f457c9a2e6d39b03c3b8a43db0'},
#     {'sha': '9747b3d51c4ee182352d7efa5ca0503ec291686c',
#      'author': {'email': '125030768+FrozenQxc@users.noreply.github.com',
#       'name': 'WUKYGE'},
#      'message': 'Merge pull request #1 from Samurai-Club/TWD-1\n\nTWD-1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Samurai-Club/Test/commits/9747b3d51c4ee182352d7efa5ca0503ec291686c'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z',
#   'org': {'id': 198628374,
#    'login': 'Samurai-Club',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Samurai-Club',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/198628374?'}},
#  {'id': '46416530610',
#   'type': 'MemberEvent',
#   'actor': {'id': 127781020,
#    'login': 'prabhathreddybhuma',
#    'display_login': 'prabhathreddybhuma',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/prabhathreddybhuma',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/127781020?'},
#   'repo': {'id': 930386271,
#    'name': 'prabhathreddybhuma/Invenex_codefest',
#    'url': 'https://api.github.com/repos/prabhathreddybhuma/Invenex_codefest'},
#   'payload': {'member': {'login': 'maneethreddy',
#     'id': 138548255,
#     'node_id': 'U_kgDOCEIUHw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/138548255?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/maneethreddy',
#     'html_url': 'https://github.com/maneethreddy',
#     'followers_url': 'https://api.github.com/users/maneethreddy/followers',
#     'following_url': 'https://api.github.com/users/maneethreddy/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/maneethreddy/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/maneethreddy/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/maneethreddy/subscriptions',
#     'organizations_url': 'https://api.github.com/users/maneethreddy/orgs',
#     'repos_url': 'https://api.github.com/users/maneethreddy/repos',
#     'events_url': 'https://api.github.com/users/maneethreddy/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/maneethreddy/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530597',
#   'type': 'PushEvent',
#   'actor': {'id': 111562259,
#    'login': 'kyrolloss',
#    'display_login': 'kyrolloss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kyrolloss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/111562259?'},
#   'repo': {'id': 858721194,
#    'name': 'samuelmagdy555/Ls-Fitness',
#    'url': 'https://api.github.com/repos/samuelmagdy555/Ls-Fitness'},
#   'payload': {'repository_id': 858721194,
#    'push_id': 22577039864,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd0ab8e25db8b707930515e43c34308da9c1982d7',
#    'before': '5a9ac7c25f91d4465b5b3a55edd82bfd89de2af2',
#    'commits': [{'sha': 'd0ab8e25db8b707930515e43c34308da9c1982d7',
#      'author': {'email': 'bolly333333@gmail.com', 'name': 'kero harby'},
#      'message': 'handel chat modification',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/samuelmagdy555/Ls-Fitness/commits/d0ab8e25db8b707930515e43c34308da9c1982d7'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530580',
#   'type': 'PushEvent',
#   'actor': {'id': 146570895,
#    'login': 'fuggi11',
#    'display_login': 'fuggi11',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fuggi11',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146570895?'},
#   'repo': {'id': 928142100,
#    'name': 'adithya2152/mentalModal',
#    'url': 'https://api.github.com/repos/adithya2152/mentalModal'},
#   'payload': {'repository_id': 928142100,
#    'push_id': 22577040926,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '85f67bfa7427d1461648380ef753a52da335ada4',
#    'before': '91e383bdfb63ceede7853824ad855059c81108c1',
#    'commits': [{'sha': '85f67bfa7427d1461648380ef753a52da335ada4',
#      'author': {'email': 'ajithaarvinth26@gmail.com', 'name': 'fuggi11'},
#      'message': 'Did the changes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adithya2152/mentalModal/commits/85f67bfa7427d1461648380ef753a52da335ada4'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530551',
#   'type': 'PushEvent',
#   'actor': {'id': 53423899,
#    'login': 'turjo997',
#    'display_login': 'turjo997',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/turjo997',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53423899?'},
#   'repo': {'id': 781578042,
#    'name': 'turjo997/SpringBoot-DesignPatterns',
#    'url': 'https://api.github.com/repos/turjo997/SpringBoot-DesignPatterns'},
#   'payload': {'repository_id': 781578042,
#    'push_id': 22577041399,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5ccb9c9a1162f3be713319000a93b0590711240b',
#    'before': 'f1c9b74e227123dd10fbfcda3bda9ffb1e4695f1',
#    'commits': [{'sha': '5ccb9c9a1162f3be713319000a93b0590711240b',
#      'author': {'email': 'turja997@gmail.com', 'name': 'turjo997'},
#      'message': 'wprking',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/turjo997/SpringBoot-DesignPatterns/commits/5ccb9c9a1162f3be713319000a93b0590711240b'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530571',
#   'type': 'PushEvent',
#   'actor': {'id': 59484808,
#    'login': 'markus6890',
#    'display_login': 'markus6890',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/markus6890',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59484808?'},
#   'repo': {'id': 775147030,
#    'name': 'markus6890/HlVagtVault',
#    'url': 'https://api.github.com/repos/markus6890/HlVagtVault'},
#   'payload': {'repository_id': 775147030,
#    'push_id': 22577041407,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '27f7dcc6a9c319461f0bd266dfc7150679552d40',
#    'before': 'a14dbe90b9d5b30035dc1b0fa9aac67c28dab9b8',
#    'commits': [{'sha': '27f7dcc6a9c319461f0bd266dfc7150679552d40',
#      'author': {'email': 'markushygedombrowski@gmail.com',
#       'name': 'markus6890'},
#      'message': 'Rasmus pay',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/markus6890/HlVagtVault/commits/27f7dcc6a9c319461f0bd266dfc7150679552d40'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530543',
#   'type': 'PushEvent',
#   'actor': {'id': 24709527,
#    'login': 'asialiugf',
#    'display_login': 'asialiugf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asialiugf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24709527?'},
#   'repo': {'id': 763347334,
#    'name': 'asialiugf/blogimages',
#    'url': 'https://api.github.com/repos/asialiugf/blogimages'},
#   'payload': {'repository_id': 763347334,
#    'push_id': 22577041376,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f860398a4854c591183daab64009fb2df0fd7cc0',
#    'before': '6f0dbbc8be6f66f414cafc5f4c187e565d6b5dec',
#    'commits': [{'sha': 'f860398a4854c591183daab64009fb2df0fd7cc0',
#      'author': {'email': '2337957910@qq.com', 'name': 'asialiugf'},
#      'message': 'Upload by PicGo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/asialiugf/blogimages/commits/f860398a4854c591183daab64009fb2df0fd7cc0'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530560',
#   'type': 'GollumEvent',
#   'actor': {'id': 22561112,
#    'login': 'Delekof',
#    'display_login': 'Delekof',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Delekof',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22561112?'},
#   'repo': {'id': 826173028,
#    'name': 'Delekof/HoD_wiki',
#    'url': 'https://api.github.com/repos/Delekof/HoD_wiki'},
#   'payload': {'pages': [{'page_name': 'Religions',
#      'title': 'Religions',
#      'summary': None,
#      'action': 'edited',
#      'sha': '0e594de9fde12ef12a62e354e871884c1024e75d',
#      'html_url': 'https://github.com/Delekof/HoD_wiki/wiki/Religions'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530503',
#   'type': 'PushEvent',
#   'actor': {'id': 62186933,
#    'login': 'StruckanDesigns',
#    'display_login': 'StruckanDesigns',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StruckanDesigns',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62186933?'},
#   'repo': {'id': 259056071,
#    'name': 'StruckanDesigns/struckandesigns.github.io',
#    'url': 'https://api.github.com/repos/StruckanDesigns/struckandesigns.github.io'},
#   'payload': {'repository_id': 259056071,
#    'push_id': 22577040905,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '31a895da3bbb2b716b3331fe94f1c09fca6c4355',
#    'before': '3075f8d6ac1560e99a714d4a53f6a47ace5f9efa',
#    'commits': [{'sha': '31a895da3bbb2b716b3331fe94f1c09fca6c4355',
#      'author': {'email': '62186933+StruckanDesigns@users.noreply.github.com',
#       'name': 'Struckan Designs'},
#      'message': 'Update terms.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StruckanDesigns/struckandesigns.github.io/commits/31a895da3bbb2b716b3331fe94f1c09fca6c4355'}]},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530525',
#   'type': 'DeleteEvent',
#   'actor': {'id': 63051881,
#    'login': 'NolanLarrabeeCopadoDemo',
#    'display_login': 'NolanLarrabeeCopadoDemo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NolanLarrabeeCopadoDemo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63051881?'},
#   'repo': {'id': 660236345,
#    'name': 'NolanLarrabeeCopadoDemo/TFDemoOrg',
#    'url': 'https://api.github.com/repos/NolanLarrabeeCopadoDemo/TFDemoOrg'},
#   'payload': {'ref': 'feature/US-0000170',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530526',
#   'type': 'WatchEvent',
#   'actor': {'id': 79881161,
#    'login': 'xytrux',
#    'display_login': 'xytrux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xytrux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79881161?'},
#   'repo': {'id': 930061341,
#    'name': 'Exploit-Master12/RigTools-2.0',
#    'url': 'https://api.github.com/repos/Exploit-Master12/RigTools-2.0'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'},
#  {'id': '46416530531',
#   'type': 'CreateEvent',
#   'actor': {'id': 77577460,
#    'login': 'Riwan25',
#    'display_login': 'Riwan25',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Riwan25',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77577460?'},
#   'repo': {'id': 739533147,
#    'name': 'Melv1C/CompetitionManagerSaaS',
#    'url': 'https://api.github.com/repos/Melv1C/CompetitionManagerSaaS'},
#   'payload': {'ref': 'add-sendEmail-checkout',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-10T17:04:40Z'}]

# %% [markdown]
# ### Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# Especifincando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'caiosm01' # username de quem vamos extrair os dados
#owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/caiosm01/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 929971125,
#   'node_id': 'R_kgDON247tQ',
#   'name': 'Alura_pipeline_dados',
#   'full_name': 'caiosm01/Alura_pipeline_dados',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/deployments',
#   'created_at': '2025-02-09T20:14:21Z',
#   'updated_at': '2025-02-09T20:19:29Z',
#   'pushed_at': '2025-02-09T20:18:57Z',
#   'git_url': 'git://github.com/caiosm01/Alura_pipeline_dados.git',
#   'ssh_url': 'git@github.com:caiosm01/Alura_pipeline_dados.git',
#   'clone_url': 'https://github.com/caiosm01/Alura_pipeline_dados.git',
#   'svn_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#   'homepage': None,
#   'size': 81953,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 930407851,
#   'node_id': 'R_kgDON3Tlqw',
#   'name': 'alura_projeto_requests',
#   'full_name': 'caiosm01/alura_projeto_requests',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/alura_projeto_requests',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests',
#   'forks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/deployments',
#   'created_at': '2025-02-10T15:32:18Z',
#   'updated_at': '2025-02-10T15:34:43Z',
#   'pushed_at': '2025-02-10T15:34:24Z',
#   'git_url': 'git://github.com/caiosm01/alura_projeto_requests.git',
#   'ssh_url': 'git@github.com:caiosm01/alura_projeto_requests.git',
#   'clone_url': 'https://github.com/caiosm01/alura_projeto_requests.git',
#   'svn_url': 'https://github.com/caiosm01/alura_projeto_requests',
#   'homepage': None,
#   'size': 42493,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 391142915,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTExNDI5MTU=',
#   'name': 'caiosm01',
#   'full_name': 'caiosm01/caiosm01',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/caiosm01',
#   'description': 'Config files for my GitHub profile.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/caiosm01',
#   'forks_url': 'https://api.github.com/repos/caiosm01/caiosm01/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/caiosm01/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm01/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/caiosm01/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm01/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/caiosm01/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm01/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/caiosm01/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm01/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/caiosm01/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm01/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm01/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/caiosm01/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/caiosm01/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/caiosm01/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/caiosm01/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/caiosm01/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm01/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm01/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm01/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm01/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/caiosm01/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/caiosm01/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm01/deployments',
#   'created_at': '2021-07-30T17:21:43Z',
#   'updated_at': '2023-09-22T17:50:17Z',
#   'pushed_at': '2023-09-22T19:45:58Z',
#   'git_url': 'git://github.com/caiosm01/caiosm01.git',
#   'ssh_url': 'git@github.com:caiosm01/caiosm01.git',
#   'clone_url': 'https://github.com/caiosm01/caiosm01.git',
#   'svn_url': 'https://github.com/caiosm01/caiosm01',
#   'homepage': 'https://github.com/caiosm01',
#   'size': 3,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['config', 'github-config'],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 774679982,
#   'node_id': 'R_kgDOLiytrg',
#   'name': 'caiosm1.github.io',
#   'full_name': 'caiosm01/caiosm1.github.io',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/caiosm1.github.io',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io',
#   'forks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/deployments',
#   'created_at': '2024-03-20T01:18:03Z',
#   'updated_at': '2024-11-14T12:03:16Z',
#   'pushed_at': '2024-11-14T12:03:12Z',
#   'git_url': 'git://github.com/caiosm01/caiosm1.github.io.git',
#   'ssh_url': 'git@github.com:caiosm01/caiosm1.github.io.git',
#   'clone_url': 'https://github.com/caiosm01/caiosm1.github.io.git',
#   'svn_url': 'https://github.com/caiosm01/caiosm1.github.io',
#   'homepage': None,
#   'size': 5160,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'unlicense',
#    'name': 'The Unlicense',
#    'spdx_id': 'Unlicense',
#    'url': 'https://api.github.com/licenses/unlicense',
#    'node_id': 'MDc6TGljZW5zZTE1'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 467736815,
#   'node_id': 'R_kgDOG-EY7w',
#   'name': 'CursoEmVideo_PythonExercicios',
#   'full_name': 'caiosm01/CursoEmVideo_PythonExercicios',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios',
#   'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/deployments',
#   'created_at': '2022-03-09T01:35:20Z',
#   'updated_at': '2022-03-09T01:56:27Z',
#   'pushed_at': '2022-03-09T01:56:20Z',
#   'git_url': 'git://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#   'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_PythonExercicios.git',
#   'clone_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#   'svn_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#   'homepage': None,
#   'size': 93881,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 467745215,
#   'node_id': 'R_kgDOG-E5vw',
#   'name': 'CursoEmVideo_WebDesign',
#   'full_name': 'caiosm01/CursoEmVideo_WebDesign',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign',
#   'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/deployments',
#   'created_at': '2022-03-09T02:10:19Z',
#   'updated_at': '2022-03-09T02:11:16Z',
#   'pushed_at': '2022-03-09T02:11:12Z',
#   'git_url': 'git://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#   'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_WebDesign.git',
#   'clone_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#   'svn_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#   'homepage': None,
#   'size': 5307,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 805422935,
#   'node_id': 'R_kgDOMAHHVw',
#   'name': 'Market_Basket_Analysis_Apriori',
#   'full_name': 'caiosm01/Market_Basket_Analysis_Apriori',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#   'description': 'Analisé de dados de uma cesta de mercado utilizando o algoritmo Apriori, com o objetivo de observar a correlação entre os produtos adquiridos pelos clientes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/deployments',
#   'created_at': '2024-05-24T14:38:51Z',
#   'updated_at': '2024-06-20T16:09:27Z',
#   'pushed_at': '2024-06-20T16:07:22Z',
#   'git_url': 'git://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#   'ssh_url': 'git@github.com:caiosm01/Market_Basket_Analysis_Apriori.git',
#   'clone_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#   'svn_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#   'homepage': None,
#   'size': 109,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 468989018,
#   'node_id': 'R_kgDOG_Q0Wg',
#   'name': 'projeto1_AnaliseDeDados_FreeCodeCamp',
#   'full_name': 'caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'forks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/deployments',
#   'created_at': '2022-03-12T05:28:44Z',
#   'updated_at': '2022-03-12T05:32:44Z',
#   'pushed_at': '2022-03-12T05:32:41Z',
#   'git_url': 'git://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'ssh_url': 'git@github.com:caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'clone_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'svn_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 468990539,
#   'node_id': 'R_kgDOG_Q6Sw',
#   'name': 'projeto1_Python_FreeCodeCamp',
#   'full_name': 'caiosm01/projeto1_Python_FreeCodeCamp',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
# ...
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/deployments',
#   'created_at': '2023-11-07T09:27:40Z',
#   'updated_at': '2023-11-07T10:36:23Z',
#   'pushed_at': '2023-11-13T01:06:25Z',
#   'git_url': 'git://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'ssh_url': 'git@github.com:caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'clone_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'svn_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis',
#   'homepage': None,
#   'size': 4810,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 814328439,
#   'node_id': 'R_kgDOMImqdw',
#   'name': 'udend-capstone-project',
#   'full_name': 'caiosm01/udend-capstone-project',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/udend-capstone-project',
#   'description': "My Capstone Project for Udacity's Nanodegree Program",
#   'fork': True,
#   'url': 'https://api.github.com/repos/caiosm01/udend-capstone-project',
#   'forks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/deployments',
#   'created_at': '2024-06-12T19:45:33Z',
#   'updated_at': '2024-06-12T19:45:33Z',
#   'pushed_at': '2021-08-03T02:43:43Z',
#   'git_url': 'git://github.com/caiosm01/udend-capstone-project.git',
#   'ssh_url': 'git@github.com:caiosm01/udend-capstone-project.git',
#   'clone_url': 'https://github.com/caiosm01/udend-capstone-project.git',
#   'svn_url': 'https://github.com/caiosm01/udend-capstone-project',
#   'homepage': None,
#   'size': 236260,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 817760189,
#   'node_id': 'R_kgDOML4HvQ',
#   'name': 'Web-Scraping---Google-Drive',
#   'full_name': 'caiosm01/Web-Scraping---Google-Drive',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/deployments',
#   'created_at': '2024-06-20T11:38:09Z',
#   'updated_at': '2024-06-20T12:26:38Z',
#   'pushed_at': '2024-06-20T12:26:35Z',
#   'git_url': 'git://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#   'ssh_url': 'git@github.com:caiosm01/Web-Scraping---Google-Drive.git',
#   'clone_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#   'svn_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#   'homepage': None,
#   'size': 9,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]

# %%
len(response.json())
# Out:
# 15

# %% [markdown]
# ### Autenticação

# %%
import os
from dotenv import load_dotenv


load_dotenv(override=True)
access_token = os.getenv("access_token")

# Especifincando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28',
           'Authorization': 'Bearer '+ access_token}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'caiosm01' # username de quem vamos extrair os dados
#owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
repos_list = []

for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 929971125,
#    'node_id': 'R_kgDON247tQ',
#    'name': 'Alura_pipeline_dados',
#    'full_name': 'caiosm01/Alura_pipeline_dados',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/deployments',
#    'created_at': '2025-02-09T20:14:21Z',
#    'updated_at': '2025-02-09T20:19:29Z',
#    'pushed_at': '2025-02-09T20:18:57Z',
#    'git_url': 'git://github.com/caiosm01/Alura_pipeline_dados.git',
#    'ssh_url': 'git@github.com:caiosm01/Alura_pipeline_dados.git',
#    'clone_url': 'https://github.com/caiosm01/Alura_pipeline_dados.git',
#    'svn_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#    'homepage': None,
#    'size': 81953,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 930407851,
#    'node_id': 'R_kgDON3Tlqw',
#    'name': 'alura_projeto_requests',
#    'full_name': 'caiosm01/alura_projeto_requests',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/alura_projeto_requests',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests',
#    'forks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/deployments',
#    'created_at': '2025-02-10T15:32:18Z',
#    'updated_at': '2025-02-10T15:34:43Z',
#    'pushed_at': '2025-02-10T15:34:24Z',
#    'git_url': 'git://github.com/caiosm01/alura_projeto_requests.git',
#    'ssh_url': 'git@github.com:caiosm01/alura_projeto_requests.git',
#    'clone_url': 'https://github.com/caiosm01/alura_projeto_requests.git',
#    'svn_url': 'https://github.com/caiosm01/alura_projeto_requests',
#    'homepage': None,
#    'size': 42493,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 391142915,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTExNDI5MTU=',
#    'name': 'caiosm01',
#    'full_name': 'caiosm01/caiosm01',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/caiosm01',
#    'description': 'Config files for my GitHub profile.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/caiosm01',
#    'forks_url': 'https://api.github.com/repos/caiosm01/caiosm01/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/caiosm01/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm01/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/caiosm01/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm01/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/caiosm01/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm01/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/caiosm01/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm01/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/caiosm01/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm01/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm01/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/caiosm01/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/caiosm01/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/caiosm01/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/caiosm01/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/caiosm01/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm01/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm01/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm01/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm01/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/caiosm01/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/caiosm01/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm01/deployments',
#    'created_at': '2021-07-30T17:21:43Z',
#    'updated_at': '2023-09-22T17:50:17Z',
#    'pushed_at': '2023-09-22T19:45:58Z',
#    'git_url': 'git://github.com/caiosm01/caiosm01.git',
#    'ssh_url': 'git@github.com:caiosm01/caiosm01.git',
#    'clone_url': 'https://github.com/caiosm01/caiosm01.git',
#    'svn_url': 'https://github.com/caiosm01/caiosm01',
#    'homepage': 'https://github.com/caiosm01',
#    'size': 3,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['config', 'github-config'],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 774679982,
#    'node_id': 'R_kgDOLiytrg',
#    'name': 'caiosm1.github.io',
#    'full_name': 'caiosm01/caiosm1.github.io',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/caiosm1.github.io',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io',
#    'forks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/deployments',
#    'created_at': '2024-03-20T01:18:03Z',
#    'updated_at': '2024-11-14T12:03:16Z',
#    'pushed_at': '2024-11-14T12:03:12Z',
#    'git_url': 'git://github.com/caiosm01/caiosm1.github.io.git',
#    'ssh_url': 'git@github.com:caiosm01/caiosm1.github.io.git',
#    'clone_url': 'https://github.com/caiosm01/caiosm1.github.io.git',
#    'svn_url': 'https://github.com/caiosm01/caiosm1.github.io',
#    'homepage': None,
#    'size': 5160,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'unlicense',
#     'name': 'The Unlicense',
#     'spdx_id': 'Unlicense',
#     'url': 'https://api.github.com/licenses/unlicense',
#     'node_id': 'MDc6TGljZW5zZTE1'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 467736815,
#    'node_id': 'R_kgDOG-EY7w',
#    'name': 'CursoEmVideo_PythonExercicios',
#    'full_name': 'caiosm01/CursoEmVideo_PythonExercicios',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios',
#    'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/deployments',
#    'created_at': '2022-03-09T01:35:20Z',
#    'updated_at': '2022-03-09T01:56:27Z',
#    'pushed_at': '2022-03-09T01:56:20Z',
#    'git_url': 'git://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#    'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_PythonExercicios.git',
#    'clone_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#    'svn_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#    'homepage': None,
#    'size': 93881,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 467745215,
#    'node_id': 'R_kgDOG-E5vw',
#    'name': 'CursoEmVideo_WebDesign',
#    'full_name': 'caiosm01/CursoEmVideo_WebDesign',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign',
#    'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/deployments',
#    'created_at': '2022-03-09T02:10:19Z',
#    'updated_at': '2022-03-09T02:11:16Z',
#    'pushed_at': '2022-03-09T02:11:12Z',
#    'git_url': 'git://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#    'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_WebDesign.git',
#    'clone_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#    'svn_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#    'homepage': None,
#    'size': 5307,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 805422935,
#    'node_id': 'R_kgDOMAHHVw',
#    'name': 'Market_Basket_Analysis_Apriori',
#    'full_name': 'caiosm01/Market_Basket_Analysis_Apriori',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#    'description': 'Analisé de dados de uma cesta de mercado utilizando o algoritmo Apriori, com o objetivo de observar a correlação entre os produtos adquiridos pelos clientes',
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/deployments',
#    'created_at': '2024-05-24T14:38:51Z',
#    'updated_at': '2024-06-20T16:09:27Z',
#    'pushed_at': '2024-06-20T16:07:22Z',
#    'git_url': 'git://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#    'ssh_url': 'git@github.com:caiosm01/Market_Basket_Analysis_Apriori.git',
#    'clone_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#    'svn_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#    'homepage': None,
#    'size': 109,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 468989018,
#    'node_id': 'R_kgDOG_Q0Wg',
#    'name': 'projeto1_AnaliseDeDados_FreeCodeCamp',
#    'full_name': 'caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'forks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/labels{/name}',
# ...
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/deployments',
#    'created_at': '2023-11-07T09:27:40Z',
#    'updated_at': '2023-11-07T10:36:23Z',
#    'pushed_at': '2023-11-13T01:06:25Z',
#    'git_url': 'git://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'ssh_url': 'git@github.com:caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'clone_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'svn_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis',
#    'homepage': None,
#    'size': 4810,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 814328439,
#    'node_id': 'R_kgDOMImqdw',
#    'name': 'udend-capstone-project',
#    'full_name': 'caiosm01/udend-capstone-project',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/udend-capstone-project',
#    'description': "My Capstone Project for Udacity's Nanodegree Program",
#    'fork': True,
#    'url': 'https://api.github.com/repos/caiosm01/udend-capstone-project',
#    'forks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/deployments',
#    'created_at': '2024-06-12T19:45:33Z',
#    'updated_at': '2024-06-12T19:45:33Z',
#    'pushed_at': '2021-08-03T02:43:43Z',
#    'git_url': 'git://github.com/caiosm01/udend-capstone-project.git',
#    'ssh_url': 'git@github.com:caiosm01/udend-capstone-project.git',
#    'clone_url': 'https://github.com/caiosm01/udend-capstone-project.git',
#    'svn_url': 'https://github.com/caiosm01/udend-capstone-project',
#    'homepage': None,
#    'size': 236260,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 817760189,
#    'node_id': 'R_kgDOML4HvQ',
#    'name': 'Web-Scraping---Google-Drive',
#    'full_name': 'caiosm01/Web-Scraping---Google-Drive',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/deployments',
#    'created_at': '2024-06-20T11:38:09Z',
#    'updated_at': '2024-06-20T12:26:38Z',
#    'pushed_at': '2024-06-20T12:26:35Z',
#    'git_url': 'git://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#    'ssh_url': 'git@github.com:caiosm01/Web-Scraping---Google-Drive.git',
#    'clone_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#    'svn_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#    'homepage': None,
#    'size': 9,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}}],
#  [],
#  [],
#  [],
#  []]

# %%
len(repos_list[0])
# Out:
# 15

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list[0][1]['name']
# Out:
# 'alura_projeto_requests'

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name
# Out:
# ['Alura_pipeline_dados',
#  'alura_projeto_requests',
#  'caiosm01',
#  'caiosm1.github.io',
#  'CursoEmVideo_PythonExercicios',
#  'CursoEmVideo_WebDesign',
#  'Market_Basket_Analysis_Apriori',
#  'projeto1_AnaliseDeDados_FreeCodeCamp',
#  'projeto1_Python_FreeCodeCamp',
#  'projeto2_AnaliseDeDados_FreeCodeCamp',
#  'projeto_engenharia_de_dados_pesquisas',
#  'teste',
#  'Transformacao_e_Encoding_de_Variaveis',
#  'udend-capstone-project',
#  'Web-Scraping---Google-Drive']

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[0][0]['language']
# Out:
# 'Python'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
repos_language
# Out:
# ['Python',
#  'Python',
#  None,
#  'HTML',
#  'Python',
#  'HTML',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  None,
#  'Python']

# %% [markdown]
# ## Criando um DataFrame

# %%
import pandas as pd
