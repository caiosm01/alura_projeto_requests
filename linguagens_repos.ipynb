# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# # Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"46446371789","type":"PullRequestReviewEvent","actor":{"id":12814114,"login":"nuno-vieira","display_login":"nuno-vieira","gravatar_id":"","url":"https://api.github.com/users/nuno-vieira","avatar_url":"https://avatars.githubusercontent.com/u/12814114?"},"repo":{"id":178428993,"name":"GetStream/stream-chat-swift","url":"https://api.github.com/repos/GetStream/stream-chat-swift"},"payload":{"action":"created","review":{"id":2608471787,"node_id":"PRR_kwDOCqKcQc6beh7r","user":{"login":"nuno-vieira","id":12814114,"node_id":"MDQ6VXNlcjEyODE0MTE0","avatar_url":"https://avatars.githubusercontent.com/u/12814114?v=4","gravatar_id":"","url":"https://api.github.com/users/nuno-vieira","html_url":"https://github.com/nuno-vieira","followers_url":"https://api.github.com/users/nuno-vieira/followers","following_url":"https://api.github.com/users/nuno-vieira/following{/other_user}","gists_url":"https://api.github.com/users/nuno-vieira/gists{/gist_id}","starred_url":"https://api.github.com/users/nuno-vieira/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/nuno-vieira/subscriptions","organizations_url":"https://api.github.com/users/nuno-vieira/orgs","repos_url":"https://api.github.com/users/nuno-vieira/repos","events_url":"https://api.github.com/users/nuno-vieira/events{/privacy}","received_events_url":"https://api.github.com/users/nuno-vieira/received_events","type":"User","user_view_type":"public","site_admin":false},"body":null,"commit_id":"f24dd643d126272b508ff925e0358b9aa7954293","submitted_at":"2025-02-11T11:41:47Z","state":"commented","html_url":"https://github.com/GetStream/stream-chat-swift/pull/3588#pullrequestreview-2608471787","pull_request_url":"https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588","author_association":"MEMBER","_links":{"html":{"href":"https://github.com/GetStream/stream-chat-swift/pull/3588#pullrequestreview-2608471787"},"pull_request":{"href":"https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588"}}},"pull_request":{"url":"https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588","id":2322854915,"node_id":"PR_kwDOCqKcQc6Kc_QD","html_url":"https://github.com/GetStream/stream-chat-swift/pull/3588","diff_url":"https://github.com/GetStream/stream-chat-swift/pull/3588.diff","patch_url":"https://github.com/GetStream/stream-chat-swift/pull/3588.patch","issue_url":"https://api.github.com/repos/GetStream/stream-chat-swift/issues/3588","number":3588,"state":"open","locked":false,"title":"Add Draft Messages Support","user":{"login":"nuno-vieira","id":12814114,"node_id":"MDQ6VXNlcjEyODE0MTE0","avatar_url":"https://avatars.githubusercontent.com/u/12814114?v=4","gravatar_id":"","url":"https://api.github.com/users/nuno-vieira","html_url":"https://github.com/nuno-vieira","followers_url":"https://api.github.com/users/nuno-vieira/followers","following_url":"https://api.github.com/users/nuno-vieira/following{/other_user}","gists_url":"https://api.github.com/users/nuno-vieira/gists{/gist_id}","starred_url":"https://api.github.com/users/nuno-vieira/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/nuno-vieira/subscriptions","organizations_url":"https://api.github.com/users/nuno-vieira/orgs","repos_url":"https://api.github.com/users/nuno-vieira/repos","events_url":"https://api.github.com/users/nuno-vieira/events{/privacy}","received_events_url":"https://api.github.com/users/nuno-vieira/received_events","type":"User","user_view_type":"public","site_admin":false},"body":"### 🔗 Issue Links\\r\\n\\r\\nhttps://linear.app/stream/issue/IOS-640/draft-messages-support\\r\\n\\r\\n### 🎯 Goal\\r\\n\\r\\n Add draft messages support.\\r\\n\\r\\n### 📝 Summary\\r\\n\\r\\nChannel Drafts:\\r\\n- `channel.draftMessage?`\\r\\n- `channelController.updateDraftMessage()`\\r\\n- `channelController.deleteDraftMessage()`\\r\\n- `channelController.loadDraftMessage()`\\r\\n\\r\\nThread Drafts:\\r\\n- `message.draftReply?`\\r\\n- `messageController.updateDraftReply()`\\r\ ...

# %%
r.json()
# Out:
# [{'id': '46446371789',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 12814114,
#    'login': 'nuno-vieira',
#    'display_login': 'nuno-vieira',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nuno-vieira',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12814114?'},
#   'repo': {'id': 178428993,
#    'name': 'GetStream/stream-chat-swift',
#    'url': 'https://api.github.com/repos/GetStream/stream-chat-swift'},
#   'payload': {'action': 'created',
#    'review': {'id': 2608471787,
#     'node_id': 'PRR_kwDOCqKcQc6beh7r',
#     'user': {'login': 'nuno-vieira',
#      'id': 12814114,
#      'node_id': 'MDQ6VXNlcjEyODE0MTE0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12814114?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nuno-vieira',
#      'html_url': 'https://github.com/nuno-vieira',
#      'followers_url': 'https://api.github.com/users/nuno-vieira/followers',
#      'following_url': 'https://api.github.com/users/nuno-vieira/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nuno-vieira/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nuno-vieira/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nuno-vieira/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nuno-vieira/orgs',
#      'repos_url': 'https://api.github.com/users/nuno-vieira/repos',
#      'events_url': 'https://api.github.com/users/nuno-vieira/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nuno-vieira/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': None,
#     'commit_id': 'f24dd643d126272b508ff925e0358b9aa7954293',
#     'submitted_at': '2025-02-11T11:41:47Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/GetStream/stream-chat-swift/pull/3588#pullrequestreview-2608471787',
#     'pull_request_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/GetStream/stream-chat-swift/pull/3588#pullrequestreview-2608471787'},
#      'pull_request': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588',
#     'id': 2322854915,
#     'node_id': 'PR_kwDOCqKcQc6Kc_QD',
#     'html_url': 'https://github.com/GetStream/stream-chat-swift/pull/3588',
#     'diff_url': 'https://github.com/GetStream/stream-chat-swift/pull/3588.diff',
#     'patch_url': 'https://github.com/GetStream/stream-chat-swift/pull/3588.patch',
#     'issue_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/3588',
#     'number': 3588,
#     'state': 'open',
#     'locked': False,
#     'title': 'Add Draft Messages Support',
#     'user': {'login': 'nuno-vieira',
#      'id': 12814114,
#      'node_id': 'MDQ6VXNlcjEyODE0MTE0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12814114?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nuno-vieira',
#      'html_url': 'https://github.com/nuno-vieira',
#      'followers_url': 'https://api.github.com/users/nuno-vieira/followers',
#      'following_url': 'https://api.github.com/users/nuno-vieira/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nuno-vieira/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nuno-vieira/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nuno-vieira/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nuno-vieira/orgs',
#      'repos_url': 'https://api.github.com/users/nuno-vieira/repos',
#      'events_url': 'https://api.github.com/users/nuno-vieira/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nuno-vieira/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': '### 🔗 Issue Links\r\n\r\nhttps://linear.app/stream/issue/IOS-640/draft-messages-support\r\n\r\n### 🎯 Goal\r\n\r\n Add draft messages support.\r\n\r\n### 📝 Summary\r\n\r\nChannel Drafts:\r\n- `channel.draftMessage?`\r\n- `channelController.updateDraftMessage()`\r\n- `channelController.deleteDraftMessage()`\r\n- `channelController.loadDraftMessage()`\r\n\r\nThread Drafts:\r\n- `message.draftReply?`\r\n- `messageController.updateDraftReply()`\r\n- `messageController.deleteDraftReply()`\r\n- `messageController.loadDraftReply()`\r\n\r\nQuery Drafts:\r\n- `currentUserController.draftMessages`\r\n- `currentUserController.deleteDraft(cid:)`\r\n- `currentUserController.loadDraftMessages()`\r\n- `currentUserController.loadMoreDraftMessages()`\r\n- `currentUserControllerDelegate.didUpdateDraftMessages()`\r\n\r\nFeature Flags:\r\n- `Components.default.isDraftMessagesEnabled`\r\n\r\nTODO:\r\n- [ ] Tests\r\n- [ ] State Layer (Possible Separate PR)\r\n\r\n### 🛠 Implementation\r\n\r\n#### User Flow\r\n\r\n```mermaid\r\nflowchart LR\r\n    A[User Action]\r\n    A -->|Leave Chat| F[Update Channel Draft]\r\n    A -->|Leave Thread| E[Update Thread Draft]\r\n    A -->|Erase Input Message| D[Delete Draft]\r\n    A -->|Publish Message| D[Delete Draft]\r\n```\r\n\r\n#### `CurrentUserController.loadDraftMessages()` vs `DraftMessagesListController`\r\nTODO\r\n\r\n#### Reusing `ChatMessage` and `MessageDTO`\r\nTODO\r\n\r\n### 🎨 Showcase\r\n\r\nhttps://github.com/user-attachments/assets/9f85c1bf-ef61-4c26-b5fc-7bc6f1c6bc87\r\n\r\n\r\n### 🧪 Manual Testing Notes\r\n\r\n<details><summary>Update a Channel Draft Message</summary>\r\n<p>\r\n\r\n1. Open a Channel\r\n2. Input some text in the composer (Optional: Include attachments, commands)\r\n3. Leave the Channel\r\n4. Comeback to the channel\r\n5. The composer should have the same content as the composer\r\n6. When going to the Channel List, the channel preview should have the draft message\r\n7. Open the channel on another device \r\n8. The composer should have the same content (Besides the attachments)\r\n\r\n</p>\r\n</details>\r\n\r\n<details><summary>Update a Thread Draft Reply</summary>\r\n<p>\r\n\r\n1. Open a Thread\r\n2. Input some text in the composer (Optional: Include attachments, commands)\r\n3. Leave the Thread\r\n4. Comeback to the Thread\r\n5. The composer should have the same content as the composer\r\n6. When going to the Thread List, the thread preview should have the draft message\r\n7. Open the thread on another device \r\n8. The composer should have the same content (Besides the attachments)\r\n\r\n</p>\r\n</details>\r\n\r\n<details><summary>Fetching all Drafts</summary>\r\n<p>\r\n\r\n1. Open the Draft tab\r\n2. All drafts should be loaded including ones in the thread\r\n3. The list should be updated whenever a draft is added or removed\r\n4. When tapping a draft from the channel, should open the channel\r\n5. When tapping a draft from a thread, should open the thread\r\n\r\n</p>\r\n</details>\r\n\r\n<details><summary>Deleting a Draft (Channel + Thread)</summary>\r\n<p>\r\n\r\n1. Open a Channel/Thread\r\n2. Input some text in the composer (Optional: Include attachments, commands)\r\n3. Leave the Channel/Thread\r\n4. Comeback to the Channel/Thread\r\n5. The composer should have the same content as the composer\r\n7. Erase the content of the composer\r\n8. Leave the Channel/Thread\r\n9. When coming back to the Channel/Thread the composer should be empty\r\n10. When coming back to the Channel List/Thread List the preview should not include the draft\r\n11. The draft should disappear from the Draft List.\r\n12. The draft should disappear on the other devices as well. (Previews and Thread List)\r\n\r\n</p>\r\n</details>\r\n\r\nKnown Issues:\r\n- Saving commands is crashing\r\n\r\n### ☑️ Contributor Checklist\r\n\r\n- [ ] I have signed the [Stream CLA](https://docs.google.com/forms/d/e/1FAIpQLScFKsKkAJI7mhCr7K9rEIOpqIDThrWxuvxnwUq2XkHyG154vQ/viewform) (required)\r\n- [x] This chang ...
#     'created_at': '2025-02-07T18:15:09Z',
#     'updated_at': '2025-02-11T11:41:47Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'e5bb3b03a33c12ab97f46fc5fe96207bddfad729',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2089308076,
#       'node_id': 'MDU6TGFiZWwyMDg5MzA4MDc2',
#       'url': 'https://api.github.com/repos/GetStream/stream-chat-swift/labels/%F0%9F%8C%90%C2%A0SDK:%20StreamChat%20(LLC)',
#       'name': '🌐\xa0SDK: StreamChat (LLC)',
#       'color': '7774cf',
#       'default': False,
#       'description': 'Tasks related to the StreamChat LLC SDK'},
#      {'id': 2459360819,
#       'node_id': 'MDU6TGFiZWwyNDU5MzYwODE5',
#       'url': 'https://api.github.com/repos/GetStream/stream-chat-swift/labels/%F0%9F%8E%A8%C2%A0SDK:%20StreamChatUI',
#       'name': '🎨\xa0SDK: StreamChatUI',
#       'color': '225836',
#       'default': False,
#       'description': 'Tasks related to the StreamChatUI SDK'},
#      {'id': 3939125213,
#       'node_id': 'LA_kwDOCqKcQc7qykfd',
#       'url': 'https://api.github.com/repos/GetStream/stream-chat-swift/labels/%E2%9C%85%C2%A0Feature',
#       'name': '✅\xa0Feature',
#       'color': '0AA131',
#       'default': False,
#       'description': 'An issue or PR related to a feature'}],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588/commits',
#     'review_comments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588/comments',
#     'review_comment_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/3588/comments',
#     'statuses_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/statuses/f24dd643d126272b508ff925e0358b9aa7954293',
#     'head': {'label': 'GetStream:add/draft-messages',
#      'ref': 'add/draft-messages',
#      'sha': 'f24dd643d126272b508ff925e0358b9aa7954293',
#      'user': {'login': 'GetStream',
#       'id': 8597527,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTc1Mjc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GetStream',
#       'html_url': 'https://github.com/GetStream',
#       'followers_url': 'https://api.github.com/users/GetStream/followers',
#       'following_url': 'https://api.github.com/users/GetStream/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GetStream/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GetStream/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GetStream/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GetStream/orgs',
#       'repos_url': 'https://api.github.com/users/GetStream/repos',
#       'events_url': 'https://api.github.com/users/GetStream/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GetStream/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 178428993,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzg0Mjg5OTM=',
#       'name': 'stream-chat-swift',
#       'full_name': 'GetStream/stream-chat-swift',
#       'private': False,
#       'owner': {'login': 'GetStream',
#        'id': 8597527,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTc1Mjc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GetStream',
#        'html_url': 'https://github.com/GetStream',
#        'followers_url': 'https://api.github.com/users/GetStream/followers',
#        'following_url': 'https://api.github.com/users/GetStream/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GetStream/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GetStream/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GetStream/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GetStream/orgs',
#        'repos_url': 'https://api.github.com/users/GetStream/repos',
#        'events_url': 'https://api.github.com/users/GetStream/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GetStream/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/GetStream/stream-chat-swift',
#       'description': '💬 iOS Chat SDK in Swift - Build your own app chat experience for iOS using the official Stream Chat API',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GetStream/stream-chat-swift',
#       'forks_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/forks',
#       'keys_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/teams',
#       'hooks_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/events',
#       'assignees_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/tags',
#       'blobs_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/languages',
#       'stargazers_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/subscription',
#       'commits_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/merges',
#       'archive_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/downloads',
#       'issues_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/deployments',
#       'created_at': '2019-03-29T15:16:46Z',
#       'updated_at': '2025-02-07T17:45:04Z',
#       'pushed_at': '2025-02-11T11:41:47Z',
#       'git_url': 'git://github.com/GetStream/stream-chat-swift.git',
#       'ssh_url': 'git@github.com:GetStream/stream-chat-swift.git',
#       'clone_url': 'https://github.com/GetStream/stream-chat-swift.git',
#       'svn_url': 'https://github.com/GetStream/stream-chat-swift',
#       'homepage': 'https://getstream.io/chat/sdk/ios/',
#       'size': 327546,
#       'stargazers_count': 876,
#       'watchers_count': 876,
#       'language': 'Swift',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 212,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['chat',
#        'chat-api',
#        'chat-application',
#        'chat-sdk',
#        'ios',
#        'ios-chat',
#        'ios-chat-sdk',
#        'ios-sdk',
#        'messaging',
#        'sdk',
#        'stream-chat',
#        'streamio',
#        'swift',
#        'swift-chat',
#        'swift-sdk'],
#       'visibility': 'public',
#       'forks': 212,
#       'open_issues': 2,
#       'watchers': 876,
#       'default_branch': 'develop'}},
#     'base': {'label': 'GetStream:develop',
#      'ref': 'develop',
#      'sha': 'cecb93ac310bfd85fa3641900abd212027e1616d',
#      'user': {'login': 'GetStream',
#       'id': 8597527,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTc1Mjc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GetStream',
#       'html_url': 'https://github.com/GetStream',
#       'followers_url': 'https://api.github.com/users/GetStream/followers',
#       'following_url': 'https://api.github.com/users/GetStream/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GetStream/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GetStream/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GetStream/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GetStream/orgs',
#       'repos_url': 'https://api.github.com/users/GetStream/repos',
#       'events_url': 'https://api.github.com/users/GetStream/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GetStream/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 178428993,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzg0Mjg5OTM=',
#       'name': 'stream-chat-swift',
#       'full_name': 'GetStream/stream-chat-swift',
#       'private': False,
#       'owner': {'login': 'GetStream',
#        'id': 8597527,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTc1Mjc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GetStream',
#        'html_url': 'https://github.com/GetStream',
#        'followers_url': 'https://api.github.com/users/GetStream/followers',
#        'following_url': 'https://api.github.com/users/GetStream/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GetStream/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GetStream/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GetStream/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GetStream/orgs',
#        'repos_url': 'https://api.github.com/users/GetStream/repos',
#        'events_url': 'https://api.github.com/users/GetStream/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GetStream/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/GetStream/stream-chat-swift',
#       'description': '💬 iOS Chat SDK in Swift - Build your own app chat experience for iOS using the official Stream Chat API',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GetStream/stream-chat-swift',
#       'forks_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/forks',
#       'keys_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/teams',
#       'hooks_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/events',
#       'assignees_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/tags',
#       'blobs_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/languages',
#       'stargazers_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/subscription',
#       'commits_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/merges',
#       'archive_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/downloads',
#       'issues_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GetStream/stream-chat-swift/deployments',
#       'created_at': '2019-03-29T15:16:46Z',
#       'updated_at': '2025-02-07T17:45:04Z',
#       'pushed_at': '2025-02-11T11:41:47Z',
#       'git_url': 'git://github.com/GetStream/stream-chat-swift.git',
#       'ssh_url': 'git@github.com:GetStream/stream-chat-swift.git',
#       'clone_url': 'https://github.com/GetStream/stream-chat-swift.git',
#       'svn_url': 'https://github.com/GetStream/stream-chat-swift',
#       'homepage': 'https://getstream.io/chat/sdk/ios/',
#       'size': 327546,
#       'stargazers_count': 876,
#       'watchers_count': 876,
#       'language': 'Swift',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 212,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['chat',
#        'chat-api',
#        'chat-application',
#        'chat-sdk',
#        'ios',
#        'ios-chat',
#        'ios-chat-sdk',
#        'ios-sdk',
#        'messaging',
#        'sdk',
#        'stream-chat',
#        'streamio',
#        'swift',
#        'swift-chat',
#        'swift-sdk'],
#       'visibility': 'public',
#       'forks': 212,
#       'open_issues': 2,
#       'watchers': 876,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588'},
#      'html': {'href': 'https://github.com/GetStream/stream-chat-swift/pull/3588'},
#      'issue': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/3588'},
#      'comments': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/issues/3588/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/pulls/3588/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/GetStream/stream-chat-swift/statuses/f24dd643d126272b508ff925e0358b9aa7954293'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 8597527,
#    'login': 'GetStream',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GetStream',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?'}},
#  {'id': '46446371788',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 904830437,
#    'name': 'edeandrea/non-deterministic-no-problem',
#    'url': 'https://api.github.com/repos/edeandrea/non-deterministic-no-problem'},
#   'payload': {'ref': 'dependabot/maven/io.quarkiverse.langchain4j-quarkus-langchain4j-bom-0.24.0',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Demo repo for my talk about testing non-deterministic things.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371780',
#   'type': 'CreateEvent',
#   'actor': {'id': 149513107,
#    'login': 'andresparadaprieto',
#    'display_login': 'andresparadaprieto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andresparadaprieto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/149513107?'},
#   'repo': {'id': 930894089,
#    'name': 'andresparadaprieto/Tarea9DWES',
#    'url': 'https://api.github.com/repos/andresparadaprieto/Tarea9DWES'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Tarea9 by Andres Parada Prieto',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371768',
#   'type': 'CreateEvent',
#   'actor': {'id': 166932664,
#    'login': 'Ahsanbutt6165',
#    'display_login': 'Ahsanbutt6165',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ahsanbutt6165',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166932664?'},
#   'repo': {'id': 827836381,
#    'name': 'Ahsanbutt6165/Redux-Counter-App',
#    'url': 'https://api.github.com/repos/Ahsanbutt6165/Redux-Counter-App'},
#   'payload': {'ref': 'feature-new-ui',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371758',
#   'type': 'CreateEvent',
#   'actor': {'id': 145766384,
#    'login': 'yluizx',
#    'display_login': 'yluizx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yluizx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145766384?'},
#   'repo': {'id': 930894072,
#    'name': 'yluizx/teste',
#    'url': 'https://api.github.com/repos/yluizx/teste'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371723',
#   'type': 'PushEvent',
#   'actor': {'id': 198740529,
#    'login': 'Lokydash',
#    'display_login': 'Lokydash',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lokydash',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/198740529?'},
#   'repo': {'id': 930874191,
#    'name': 'Lokydash/Gravity',
#    'url': 'https://api.github.com/repos/Lokydash/Gravity'},
#   'payload': {'repository_id': 930874191,
#    'push_id': 22592316593,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5cc8e51a4354da0d9268aa54e0b6ac8dea4cde35',
#    'before': '9cb4fb40b57eaf5b41dd48820cd1215cc802df2b',
#    'commits': [{'sha': '5cc8e51a4354da0d9268aa54e0b6ac8dea4cde35',
#      'author': {'email': 'lokydm01@gmail.com', 'name': 'Lokydash'},
#      'message': 'Rename Index.html to index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lokydash/Gravity/commits/5cc8e51a4354da0d9268aa54e0b6ac8dea4cde35'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371688',
#   'type': 'PushEvent',
#   'actor': {'id': 60696064,
#    'login': 'Luffeboy',
#    'display_login': 'Luffeboy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Luffeboy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60696064?'},
#   'repo': {'id': 930883352,
#    'name': 'Luffeboy/Colabstuff',
#    'url': 'https://api.github.com/repos/Luffeboy/Colabstuff'},
#   'payload': {'repository_id': 930883352,
#    'push_id': 22592316625,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bc8590fdce99471239da4fb9460859cc8b965a34',
#    'before': '2d7a658c82068e63bab5530835d2b8efd96e35e5',
#    'commits': [{'sha': 'bc8590fdce99471239da4fb9460859cc8b965a34',
#      'author': {'email': '60696064+Luffeboy@users.noreply.github.com',
#       'name': 'Luffeboy'},
#      'message': 'Oprettet med Colab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Luffeboy/Colabstuff/commits/bc8590fdce99471239da4fb9460859cc8b965a34'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371706',
#   'type': 'PushEvent',
#   'actor': {'id': 179436218,
#    'login': 'dhandtanmay2612',
#    'display_login': 'dhandtanmay2612',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dhandtanmay2612',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/179436218?'},
#   'repo': {'id': 922986589,
#    'name': 'dhandtanmay2612/Code-Radar-Solutions',
#    'url': 'https://api.github.com/repos/dhandtanmay2612/Code-Radar-Solutions'},
#   'payload': {'repository_id': 922986589,
#    'push_id': 22592316570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '52d5be400d80e2e3b77a9bf2d5c2a32f19225375',
#    'before': '7a24034e80a882b59725f8dbbc41ec522eb7bc16',
#    'commits': [{'sha': '52d5be400d80e2e3b77a9bf2d5c2a32f19225375',
#      'author': {'email': 'tanmaydhand834@gmail.com',
#       'name': 'dhandtanmay2612'},
#      'message': 'Solution to Check if a Number is Prime or Not',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dhandtanmay2612/Code-Radar-Solutions/commits/52d5be400d80e2e3b77a9bf2d5c2a32f19225375'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371716',
#   'type': 'PushEvent',
#   'actor': {'id': 101036617,
#    'login': 'elmurodvokhidov',
#    'display_login': 'elmurodvokhidov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elmurodvokhidov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101036617?'},
#   'repo': {'id': 926608532,
#    'name': 'elmurodvokhidov/uni-lib',
#    'url': 'https://api.github.com/repos/elmurodvokhidov/uni-lib'},
#   'payload': {'repository_id': 926608532,
#    'push_id': 22592316645,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '685e4bdd762a347292da1bd9f5baaf5c6ece3ba1',
#    'before': 'd1fcb856f48c4a89051654553211ebef8782bdc5',
#    'commits': [{'sha': '685e4bdd762a347292da1bd9f5baaf5c6ece3ba1',
#      'author': {'email': 'elmurodvkh@gmail.com', 'name': 'unknown'},
#      'message': 'home layout',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/elmurodvokhidov/uni-lib/commits/685e4bdd762a347292da1bd9f5baaf5c6ece3ba1'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371711',
#   'type': 'PushEvent',
#   'actor': {'id': 151132724,
#    'login': 'keeptogithub',
#    'display_login': 'keeptogithub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keeptogithub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151132724?'},
#   'repo': {'id': 930893492,
#    'name': 'keeptogithub/black',
#    'url': 'https://api.github.com/repos/keeptogithub/black'},
#   'payload': {'repository_id': 930893492,
#    'push_id': 22592316672,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6c1ac6a2fa2c630858c35794b81392e2e45166fb',
#    'before': 'e3c89d62eb43bab762c10bba07dabf0da3ecb976',
#    'commits': [{'sha': '6c1ac6a2fa2c630858c35794b81392e2e45166fb',
#      'author': {'email': '151132724+keeptogithub@users.noreply.github.com',
#       'name': 'keeptogithub'},
#      'message': 'Update pic.json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/keeptogithub/black/commits/6c1ac6a2fa2c630858c35794b81392e2e45166fb'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371708',
#   'type': 'PushEvent',
#   'actor': {'id': 129070827,
#    'login': 'yohan-oc',
#    'display_login': 'yohan-oc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yohan-oc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/129070827?'},
#   'repo': {'id': 919440602,
#    'name': 'yohan-oc/turing-trust-warehouse-frontend',
#    'url': 'https://api.github.com/repos/yohan-oc/turing-trust-warehouse-frontend'},
#   'payload': {'repository_id': 919440602,
#    'push_id': 22592316603,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '53fa2fd837a52f3248b49a934c52fc7c817b39d7',
#    'before': 'e3969c14a3ef589d0953adcd06e70d0809161e2e',
#    'commits': [{'sha': '53fa2fd837a52f3248b49a934c52fc7c817b39d7',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'deploy: 16d08892b6fb180584e7e5139b4e066a0b5a2c8b',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yohan-oc/turing-trust-warehouse-frontend/commits/53fa2fd837a52f3248b49a934c52fc7c817b39d7'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371705',
#   'type': 'PushEvent',
#   'actor': {'id': 12440608,
#    'login': 'NikitaSedyx',
#    'display_login': 'NikitaSedyx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NikitaSedyx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12440608?'},
#   'repo': {'id': 563324487,
#    'name': 'folio-org/mod-bulk-operations',
#    'url': 'https://api.github.com/repos/folio-org/mod-bulk-operations'},
#   'payload': {'repository_id': 563324487,
#    'push_id': 22592316656,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b86b05ba981ddd2fe8f41f8a38004c64016a823d',
#    'before': 'ac8bcb05bda131ab2c9e6bde7abdbdf6cb670bb3',
#    'commits': [{'sha': 'b86b05ba981ddd2fe8f41f8a38004c64016a823d',
#      'author': {'email': 'mikita_siadykh@epam.com', 'name': 'Mikita Siadykh'},
#      'message': 'Add missed permissions (#372)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/folio-org/mod-bulk-operations/commits/b86b05ba981ddd2fe8f41f8a38004c64016a823d'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 16495055,
#    'login': 'folio-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/folio-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16495055?'}},
#  {'id': '46446371692',
#   'type': 'PushEvent',
#   'actor': {'id': 181813695,
#    'login': 'mikarmar-github-app[bot]',
#    'display_login': 'mikarmar-github-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikarmar-github-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/181813695?'},
#   'repo': {'id': 930894024,
#    'name': 'staticwebapps-runner-mikarmar/swa87c98e6da16d42d9bf91b3f6b880cafd',
#    'url': 'https://api.github.com/repos/staticwebapps-runner-mikarmar/swa87c98e6da16d42d9bf91b3f6b880cafd'},
#   'payload': {'repository_id': 930894024,
#    'push_id': 22592316612,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2e1c9265e6cd0882d9ac15608a0043320b1c519d',
#    'before': '80c148520e6aedd4a45560cd4a447861d4753255',
#    'commits': [{'sha': '2e1c9265e6cd0882d9ac15608a0043320b1c519d',
#      'author': {'email': '181813695+mikarmar-github-app[bot]@users.noreply.github.com',
#       'name': 'mikarmar-github-app[bot]'},
#      'message': 'Writing file api/GetMessage.cs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/staticwebapps-runner-mikarmar/swa87c98e6da16d42d9bf91b3f6b880cafd/commits/2e1c9265e6cd0882d9ac15608a0043320b1c519d'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 181813545,
#    'login': 'staticwebapps-runner-mikarmar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/staticwebapps-runner-mikarmar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/181813545?'}},
#  {'id': '46446371694',
#   'type': 'PushEvent',
#   'actor': {'id': 60321253,
#    'login': 'nicode3141',
#    'display_login': 'nicode3141',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nicode3141',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60321253?'},
#   'repo': {'id': 930891372,
#    'name': 'nicode3141/NextJS-Cookie-Game',
#    'url': 'https://api.github.com/repos/nicode3141/NextJS-Cookie-Game'},
#   'payload': {'repository_id': 930891372,
#    'push_id': 22592316676,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e7390092b7bcfe2f14791748b655e33fdf77f28c',
#    'before': '89deaa4aa3a69dfe8b5ebfce0d83c466bef7ac1d',
#    'commits': [{'sha': 'e7390092b7bcfe2f14791748b655e33fdf77f28c',
#      'author': {'email': 'nicolas.d.pfeifer@gmail.com', 'name': 'nicode3141'},
#      'message': 'Readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nicode3141/NextJS-Cookie-Game/commits/e7390092b7bcfe2f14791748b655e33fdf77f28c'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371673',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 930798687,
#    'name': 'tranyiawqilong/refactored-octo-telegram',
#    'url': 'https://api.github.com/repos/tranyiawqilong/refactored-octo-telegram'},
#   'payload': {'repository_id': 930798687,
#    'push_id': 22592316660,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8ee68517e67c1c75b5a34c9b525e7f16d44a3238',
#    'before': '2b357ab1b96f118380d37b91916f6c917a2f3932',
#    'commits': [{'sha': '8ee68517e67c1c75b5a34c9b525e7f16d44a3238',
#      'author': {'email': 'qilong711@mail.com', 'name': 'tranyiawqilong'},
#      'message': '2019-01-23T11:41:46+00:00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tranyiawqilong/refactored-octo-telegram/commits/8ee68517e67c1c75b5a34c9b525e7f16d44a3238'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371668',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 843185028,
#    'name': 'YuriJesusVedovate/YuriJesusVedovate',
#    'url': 'https://api.github.com/repos/YuriJesusVedovate/YuriJesusVedovate'},
#   'payload': {'repository_id': 843185028,
#    'push_id': 22592316588,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '597eb2cb0f28d0122f8092c4c0e2967cfaf00435',
#    'before': '85839b0b89e83fdf36a7cc8ce43ff3d362b98925',
#    'commits': [{'sha': '597eb2cb0f28d0122f8092c4c0e2967cfaf00435',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YuriJesusVedovate/YuriJesusVedovate/commits/597eb2cb0f28d0122f8092c4c0e2967cfaf00435'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371682',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 30502554,
#    'login': 'FannyLecuy',
#    'display_login': 'FannyLecuy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FannyLecuy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30502554?'},
#   'repo': {'id': 699773386,
#    'name': 'Geoplateforme/geoplateforme.github.io',
#    'url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io/issues/66',
#     'repository_url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io',
#     'labels_url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io/issues/66/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io/issues/66/comments',
#     'events_url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io/issues/66/events',
#     'html_url': 'https://github.com/Geoplateforme/geoplateforme.github.io/issues/66',
#     'id': 2842504535,
#     'node_id': 'I_kwDOKbWxys6pbS1X',
#     'number': 66,
#     'title': 'Superposition rasters et transparence',
#     'user': {'login': 'FannyLecuy',
#      'id': 30502554,
#      'node_id': 'MDQ6VXNlcjMwNTAyNTU0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30502554?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/FannyLecuy',
#      'html_url': 'https://github.com/FannyLecuy',
#      'followers_url': 'https://api.github.com/users/FannyLecuy/followers',
#      'following_url': 'https://api.github.com/users/FannyLecuy/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/FannyLecuy/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/FannyLecuy/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/FannyLecuy/subscriptions',
#      'organizations_url': 'https://api.github.com/users/FannyLecuy/orgs',
#      'repos_url': 'https://api.github.com/users/FannyLecuy/repos',
#      'events_url': 'https://api.github.com/users/FannyLecuy/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/FannyLecuy/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 6036942909,
#       'node_id': 'LA_kwDOKbWxys8AAAABZ9RwPQ',
#       'url': 'https://api.github.com/repos/Geoplateforme/geoplateforme.github.io/labels/question',
#       'name': 'question',
#       'color': 'd876e3',
#       'default': True,
#       'description': 'Further information is requested'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'Dolite',
#      'id': 8670598,
#      'node_id': 'MDQ6VXNlcjg2NzA1OTg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/8670598?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Dolite',
#      'html_url': 'https://github.com/Dolite',
#      'followers_url': 'https://api.github.com/users/Dolite/followers',
#      'following_url': 'https://api.github.com/users/Dolite/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Dolite/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Dolite/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Dolite/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Dolite/orgs',
#      'repos_url': 'https://api.github.com/users/Dolite/repos',
#      'events_url': 'https://api.github.com/users/Dolite/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Dolite/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'Dolite',
#       'id': 8670598,
#       'node_id': 'MDQ6VXNlcjg2NzA1OTg=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8670598?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Dolite',
#       'html_url': 'https://github.com/Dolite',
#       'followers_url': 'https://api.github.com/users/Dolite/followers',
#       'following_url': 'https://api.github.com/users/Dolite/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Dolite/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Dolite/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Dolite/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Dolite/orgs',
#       'repos_url': 'https://api.github.com/users/Dolite/repos',
#       'events_url': 'https://api.github.com/users/Dolite/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Dolite/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      {'login': 'FannyLecuy',
#       'id': 30502554,
#       'node_id': 'MDQ6VXNlcjMwNTAyNTU0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/30502554?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/FannyLecuy',
#       'html_url': 'https://github.com/FannyLecuy',
#       'followers_url': 'https://api.github.com/users/FannyLecuy/followers',
#       'following_url': 'https://api.github.com/users/FannyLecuy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/FannyLecuy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FannyLecuy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FannyLecuy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FannyLecuy/orgs',
#       'repos_url': 'https://api.github.com/users/FannyLecuy/repos',
#       'events_url': 'https://api.github.com/users/FannyLecuy/events{/privacy}',
# ...
#        'url': 'https://api.github.com/licenses/mpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTE0'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': True,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/pulls/18'},
#      'html': {'href': 'https://github.com/zepben/ewb-sdk-examples-python/pull/18'},
#      'issue': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/issues/18'},
#      'comments': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/issues/18/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/pulls/18/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/pulls/18/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/zepben/ewb-sdk-examples-python/statuses/b148fd5fde9ef762ad74df3a04f19da9c02314d4'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 926,
#     'deletions': 203,
#     'changed_files': 23}},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 71613669,
#    'login': 'zepben',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zepben',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71613669?'}},
#  {'id': '46446371641',
#   'type': 'PushEvent',
#   'actor': {'id': 71794290,
#    'login': 'alessandrochiaiese',
#    'display_login': 'alessandrochiaiese',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alessandrochiaiese',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71794290?'},
#   'repo': {'id': 914822976,
#    'name': 'alessandrochiaiese/getref',
#    'url': 'https://api.github.com/repos/alessandrochiaiese/getref'},
#   'payload': {'repository_id': 914822976,
#    'push_id': 22592316576,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7015598d6c93800779b8ae6e05f6723f6f3f278a',
#    'before': '0c6e2117d4da3d190f289494ffcef9c72c0bd303',
#    'commits': [{'sha': '7015598d6c93800779b8ae6e05f6723f6f3f278a',
#      'author': {'email': 'alessandro.chiaiese@libero.it', 'name': 'Chaiyes'},
#      'message': 'Updated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alessandrochiaiese/getref/commits/7015598d6c93800779b8ae6e05f6723f6f3f278a'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371629',
#   'type': 'PushEvent',
#   'actor': {'id': 20794991,
#    'login': 'testableapple',
#    'display_login': 'testableapple',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/testableapple',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20794991?'},
#   'repo': {'id': 178428993,
#    'name': 'GetStream/stream-chat-swift',
#    'url': 'https://api.github.com/repos/GetStream/stream-chat-swift'},
#   'payload': {'repository_id': 178428993,
#    'push_id': 22592316585,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ci/snapshots-recording-improvement',
#    'head': '167aa8cd300d233cd6e8f36be2549ad9167b150c',
#    'before': 'a025746984ef7b7a4454322c0ad34f495c66f95a',
#    'commits': [{'sha': '167aa8cd300d233cd6e8f36be2549ad9167b150c',
#      'author': {'email': 'alex@testableapple.com',
#       'name': 'Alexey Alter-Pesotskiy'},
#      'message': '[CI] Snapshots recording improvement',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GetStream/stream-chat-swift/commits/167aa8cd300d233cd6e8f36be2549ad9167b150c'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 8597527,
#    'login': 'GetStream',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GetStream',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8597527?'}},
#  {'id': '46446371639',
#   'type': 'PublicEvent',
#   'actor': {'id': 51475930,
#    'login': 'harsh08881',
#    'display_login': 'harsh08881',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harsh08881',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51475930?'},
#   'repo': {'id': 918542358,
#    'name': 'harsh08881/OpenChat-B',
#    'url': 'https://api.github.com/repos/harsh08881/OpenChat-B'},
#   'payload': {},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371613',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 930885303,
#    'name': 'Rakshitha-5689/skills-introduction-to-github',
#    'url': 'https://api.github.com/repos/Rakshitha-5689/skills-introduction-to-github'},
#   'payload': {'repository_id': 930885303,
#    'push_id': 22592316582,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3ce0d6e247ad9eeace305e8f72cf47fb0167901b',
#    'before': 'd5c8228d9f7c1cab669bdbc8c4d6495e638107b1',
#    'commits': [{'sha': '3ce0d6e247ad9eeace305e8f72cf47fb0167901b',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update to 4 in STEP and README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rakshitha-5689/skills-introduction-to-github/commits/3ce0d6e247ad9eeace305e8f72cf47fb0167901b'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371636',
#   'type': 'WatchEvent',
#   'actor': {'id': 100020988,
#    'login': 'AbyssSkb',
#    'display_login': 'AbyssSkb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AbyssSkb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100020988?'},
#   'repo': {'id': 881458615,
#    'name': 'browser-use/browser-use',
#    'url': 'https://api.github.com/repos/browser-use/browser-use'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 192012301,
#    'login': 'browser-use',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/browser-use',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/192012301?'}},
#  {'id': '46446371600',
#   'type': 'PushEvent',
#   'actor': {'id': 196647621,
#    'login': 'lahaneshital21',
#    'display_login': 'lahaneshital21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lahaneshital21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/196647621?'},
#   'repo': {'id': 923010407,
#    'name': 'lahaneshital21/market25',
#    'url': 'https://api.github.com/repos/lahaneshital21/market25'},
#   'payload': {'repository_id': 923010407,
#    'push_id': 22592316444,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b4fb36cf4f805cbe688b5a4800a9d1cdf4826078',
#    'before': '8cc0ceb7a0db6fddce41eca1a45bdd97c46c9211',
#    'commits': [{'sha': 'b4fb36cf4f805cbe688b5a4800a9d1cdf4826078',
#      'author': {'email': 'lahaneshital21@gmail.com', 'name': 'lahaneshital21'},
#      'message': 'Create Germany-Mobile-Phone-Liquid-Metal-Market-Size-2025-Overview-Manufacturers-Types-Applications-Share-Growth-Rate-and-Forecast-2032.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lahaneshital21/market25/commits/b4fb36cf4f805cbe688b5a4800a9d1cdf4826078'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371588',
#   'type': 'PushEvent',
#   'actor': {'id': 9142320,
#    'login': 'akaer',
#    'display_login': 'akaer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akaer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9142320?'},
#   'repo': {'id': 199404429,
#    'name': 'OneIdentity/IdentityManager.PoSh',
#    'url': 'https://api.github.com/repos/OneIdentity/IdentityManager.PoSh'},
#   'payload': {'repository_id': 199404429,
#    'push_id': 22592316577,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '0793249a59c9e80eb4f420475e789d89b5695647',
#    'before': 'f1becddf752fc918e1ec6ead0922791f15abfd1e',
#    'commits': [{'sha': '651f61d59c5e612f4b5c00ffb0635b69d79464c8',
#      'author': {'email': 'andre.raabe@quest.com', 'name': 'André Raabe'},
#      'message': 'Fix #46: Wrong parameter type for Invoke-ImEvent event parameters',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OneIdentity/IdentityManager.PoSh/commits/651f61d59c5e612f4b5c00ffb0635b69d79464c8'},
#     {'sha': '0793249a59c9e80eb4f420475e789d89b5695647',
#      'author': {'email': 'akaer@users.noreply.github.com',
#       'name': 'André R͡a͡abe'},
#      'message': 'Merge pull request #47 from akaer/change/master/fix_issue_46\n\nFix #46: Wrong parameter type for Invoke-ImEvent event parameters',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OneIdentity/IdentityManager.PoSh/commits/0793249a59c9e80eb4f420475e789d89b5695647'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z',
#   'org': {'id': 30873828,
#    'login': 'OneIdentity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OneIdentity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30873828?'}},
#  {'id': '46446371556',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 930794081,
#    'name': 'tranyiawqilong/super-spoon',
#    'url': 'https://api.github.com/repos/tranyiawqilong/super-spoon'},
#   'payload': {'repository_id': 930794081,
#    'push_id': 22592316487,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '105386b2196af68a86310c34dc5c4816aa12da2a',
#    'before': '6a62e8f9a06f465e5bdb5e6cbfca5daeef6ab573',
#    'commits': [{'sha': '105386b2196af68a86310c34dc5c4816aa12da2a',
#      'author': {'email': 'qilong711@mail.com', 'name': 'tranyiawqilong'},
#      'message': '2024-11-17T11:41:45+00:00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tranyiawqilong/super-spoon/commits/105386b2196af68a86310c34dc5c4816aa12da2a'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371566',
#   'type': 'PushEvent',
#   'actor': {'id': 62850662,
#    'login': 'yaninyzwitty',
#    'display_login': 'yaninyzwitty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yaninyzwitty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62850662?'},
#   'repo': {'id': 919108756,
#    'name': 'yaninyzwitty/gqlgen-subscriptions-go',
#    'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go'},
#   'payload': {'repository_id': 919108756,
#    'push_id': 22592316547,
#    'size': 5,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bd5872e957aead652e9435d6c5b67ad81c911e9d',
#    'before': 'a59d65dcb4a45e59adf868e77fd947e2a30d848f',
#    'commits': [{'sha': '603d1d869bacaac9029e174c7594d5c33cf08660',
#      'author': {'email': '62850662+yaninyzwitty@users.noreply.github.com',
#       'name': 'Ian Mwangi'},
#      'message': 'Merge pull request #19 from yaninyzwitty/main\n\nmerge pull requests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go/commits/603d1d869bacaac9029e174c7594d5c33cf08660'},
#     {'sha': 'ab1f7aee0705f38e8e20d23009fdcbe55f8a1fbe',
#      'author': {'email': 'ianmwa143@gmail.com', 'name': 'yaninyzwitty'},
#      'message': 'add tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go/commits/ab1f7aee0705f38e8e20d23009fdcbe55f8a1fbe'},
#     {'sha': 'a3ab8401fb1b17d592160bf2482eddca1d3c96c1',
#      'author': {'email': 'ianmwa143@gmail.com', 'name': 'yaninyzwitty'},
#      'message': "Merge branch 'develop' of https://github.com/yaninyzwitty/gqlgen-subscriptions-go into develop",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go/commits/a3ab8401fb1b17d592160bf2482eddca1d3c96c1'},
#     {'sha': '0424b9d6ee9032bda8efadbd7f381c642312ddc5',
#      'author': {'email': 'ianmwa143@gmail.com', 'name': 'yaninyzwitty'},
#      'message': 'add tests for kafka',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go/commits/0424b9d6ee9032bda8efadbd7f381c642312ddc5'},
#     {'sha': 'bd5872e957aead652e9435d6c5b67ad81c911e9d',
#      'author': {'email': '62850662+yaninyzwitty@users.noreply.github.com',
#       'name': 'Ian Mwangi'},
#      'message': 'Merge pull request #20 from yaninyzwitty/develop\n\nAdd tests for kafka',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yaninyzwitty/gqlgen-subscriptions-go/commits/bd5872e957aead652e9435d6c5b67ad81c911e9d'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371568',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 396847027,
#    'name': 'jorgecasar/BOCMadrid',
#    'url': 'https://api.github.com/repos/jorgecasar/BOCMadrid'},
#   'payload': {'repository_id': 396847027,
#    'push_id': 22592316575,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bocm/2025-02-11',
#    'head': '4baf36525eb8cd5e6bf2fc2210e8f6d029f8eb7a',
#    'before': 'b9240757f5c0810c87e965712e36292c2f30b7d4',
#    'commits': [{'sha': '4baf36525eb8cd5e6bf2fc2210e8f6d029f8eb7a',
#      'author': {'email': 'jorgecasar@users.noreply.github.com',
#       'name': 'jorgecasar'},
#      'message': 'Remove sent notification',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jorgecasar/BOCMadrid/commits/4baf36525eb8cd5e6bf2fc2210e8f6d029f8eb7a'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'},
#  {'id': '46446371557',
#   'type': 'PushEvent',
#   'actor': {'id': 72967260,
#    'login': 'Ri-Nai',
#    'display_login': 'Ri-Nai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ri-Nai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72967260?'},
#   'repo': {'id': 930465218,
#    'name': 'Ri-Nai/Ri-Nai.github.io',
#    'url': 'https://api.github.com/repos/Ri-Nai/Ri-Nai.github.io'},
#   'payload': {'repository_id': 930465218,
#    'push_id': 22592316551,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': '6b215bd699386a42e065557c7668361e4f29e7dc',
#    'before': '064d3cb6f4d7f2d2834bf6174d5e362109f40efa',
#    'commits': [{'sha': '692007332ddff78e9e581db58d3bb162292179ed',
#      'author': {'email': 'Ri_Nai_@outlook.com', 'name': 'Ri-Nai'},
#      'message': '✨ 重构配置管理，将 config.ts 文件替换为 config.yaml，优化数据加载方式',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ri-Nai/Ri-Nai.github.io/commits/692007332ddff78e9e581db58d3bb162292179ed'},
#     {'sha': '859cb12c82776d31c36b3e020e7cb7555aec3afd',
#      'author': {'email': 'Ri_Nai_@outlook.com', 'name': 'Ri-Nai'},
#      'message': '✅ 添加 Steam 图标和链接到配置文件中',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ri-Nai/Ri-Nai.github.io/commits/859cb12c82776d31c36b3e020e7cb7555aec3afd'},
#     {'sha': '6b215bd699386a42e065557c7668361e4f29e7dc',
#      'author': {'email': 'Ri_Nai_@outlook.com', 'name': 'Ri-Nai'},
#      'message': '💄 优化 MenuButton 组件，修复链接和图标的处理逻辑',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ri-Nai/Ri-Nai.github.io/commits/6b215bd699386a42e065557c7668361e4f29e7dc'}]},
#   'public': True,
#   'created_at': '2025-02-11T11:41:48Z'}]

# %% [markdown]
# ### Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# Especifincando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'caiosm01' # username de quem vamos extrair os dados
#owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/caiosm01/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 929971125,
#   'node_id': 'R_kgDON247tQ',
#   'name': 'Alura_pipeline_dados',
#   'full_name': 'caiosm01/Alura_pipeline_dados',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/deployments',
#   'created_at': '2025-02-09T20:14:21Z',
#   'updated_at': '2025-02-09T20:19:29Z',
#   'pushed_at': '2025-02-09T20:18:57Z',
#   'git_url': 'git://github.com/caiosm01/Alura_pipeline_dados.git',
#   'ssh_url': 'git@github.com:caiosm01/Alura_pipeline_dados.git',
#   'clone_url': 'https://github.com/caiosm01/Alura_pipeline_dados.git',
#   'svn_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#   'homepage': None,
#   'size': 81953,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 930407851,
#   'node_id': 'R_kgDON3Tlqw',
#   'name': 'alura_projeto_requests',
#   'full_name': 'caiosm01/alura_projeto_requests',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/alura_projeto_requests',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests',
#   'forks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/deployments',
#   'created_at': '2025-02-10T15:32:18Z',
#   'updated_at': '2025-02-10T21:14:37Z',
#   'pushed_at': '2025-02-10T21:14:25Z',
#   'git_url': 'git://github.com/caiosm01/alura_projeto_requests.git',
#   'ssh_url': 'git@github.com:caiosm01/alura_projeto_requests.git',
#   'clone_url': 'https://github.com/caiosm01/alura_projeto_requests.git',
#   'svn_url': 'https://github.com/caiosm01/alura_projeto_requests',
#   'homepage': None,
#   'size': 65364,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 391142915,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTExNDI5MTU=',
#   'name': 'caiosm01',
#   'full_name': 'caiosm01/caiosm01',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/caiosm01',
#   'description': 'Config files for my GitHub profile.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/caiosm01',
#   'forks_url': 'https://api.github.com/repos/caiosm01/caiosm01/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/caiosm01/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm01/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/caiosm01/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm01/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/caiosm01/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm01/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/caiosm01/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm01/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/caiosm01/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm01/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm01/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/caiosm01/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/caiosm01/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/caiosm01/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/caiosm01/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/caiosm01/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm01/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm01/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm01/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm01/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/caiosm01/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/caiosm01/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm01/deployments',
#   'created_at': '2021-07-30T17:21:43Z',
#   'updated_at': '2023-09-22T17:50:17Z',
#   'pushed_at': '2023-09-22T19:45:58Z',
#   'git_url': 'git://github.com/caiosm01/caiosm01.git',
#   'ssh_url': 'git@github.com:caiosm01/caiosm01.git',
#   'clone_url': 'https://github.com/caiosm01/caiosm01.git',
#   'svn_url': 'https://github.com/caiosm01/caiosm01',
#   'homepage': 'https://github.com/caiosm01',
#   'size': 3,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['config', 'github-config'],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 774679982,
#   'node_id': 'R_kgDOLiytrg',
#   'name': 'caiosm1.github.io',
#   'full_name': 'caiosm01/caiosm1.github.io',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/caiosm1.github.io',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io',
#   'forks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/deployments',
#   'created_at': '2024-03-20T01:18:03Z',
#   'updated_at': '2024-11-14T12:03:16Z',
#   'pushed_at': '2024-11-14T12:03:12Z',
#   'git_url': 'git://github.com/caiosm01/caiosm1.github.io.git',
#   'ssh_url': 'git@github.com:caiosm01/caiosm1.github.io.git',
#   'clone_url': 'https://github.com/caiosm01/caiosm1.github.io.git',
#   'svn_url': 'https://github.com/caiosm01/caiosm1.github.io',
#   'homepage': None,
#   'size': 5160,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'unlicense',
#    'name': 'The Unlicense',
#    'spdx_id': 'Unlicense',
#    'url': 'https://api.github.com/licenses/unlicense',
#    'node_id': 'MDc6TGljZW5zZTE1'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 467736815,
#   'node_id': 'R_kgDOG-EY7w',
#   'name': 'CursoEmVideo_PythonExercicios',
#   'full_name': 'caiosm01/CursoEmVideo_PythonExercicios',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios',
#   'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/deployments',
#   'created_at': '2022-03-09T01:35:20Z',
#   'updated_at': '2022-03-09T01:56:27Z',
#   'pushed_at': '2022-03-09T01:56:20Z',
#   'git_url': 'git://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#   'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_PythonExercicios.git',
#   'clone_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#   'svn_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#   'homepage': None,
#   'size': 93881,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 467745215,
#   'node_id': 'R_kgDOG-E5vw',
#   'name': 'CursoEmVideo_WebDesign',
#   'full_name': 'caiosm01/CursoEmVideo_WebDesign',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign',
#   'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/deployments',
#   'created_at': '2022-03-09T02:10:19Z',
#   'updated_at': '2022-03-09T02:11:16Z',
#   'pushed_at': '2022-03-09T02:11:12Z',
#   'git_url': 'git://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#   'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_WebDesign.git',
#   'clone_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#   'svn_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#   'homepage': None,
#   'size': 5307,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 805422935,
#   'node_id': 'R_kgDOMAHHVw',
#   'name': 'Market_Basket_Analysis_Apriori',
#   'full_name': 'caiosm01/Market_Basket_Analysis_Apriori',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#   'description': 'Analisé de dados de uma cesta de mercado utilizando o algoritmo Apriori, com o objetivo de observar a correlação entre os produtos adquiridos pelos clientes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/deployments',
#   'created_at': '2024-05-24T14:38:51Z',
#   'updated_at': '2024-06-20T16:09:27Z',
#   'pushed_at': '2024-06-20T16:07:22Z',
#   'git_url': 'git://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#   'ssh_url': 'git@github.com:caiosm01/Market_Basket_Analysis_Apriori.git',
#   'clone_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#   'svn_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#   'homepage': None,
#   'size': 109,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 468989018,
#   'node_id': 'R_kgDOG_Q0Wg',
#   'name': 'projeto1_AnaliseDeDados_FreeCodeCamp',
#   'full_name': 'caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'forks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/deployments',
#   'created_at': '2022-03-12T05:28:44Z',
#   'updated_at': '2022-03-12T05:32:44Z',
#   'pushed_at': '2022-03-12T05:32:41Z',
#   'git_url': 'git://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'ssh_url': 'git@github.com:caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'clone_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp.git',
#   'svn_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 468990539,
#   'node_id': 'R_kgDOG_Q6Sw',
#   'name': 'projeto1_Python_FreeCodeCamp',
#   'full_name': 'caiosm01/projeto1_Python_FreeCodeCamp',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
# ...
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/deployments',
#   'created_at': '2023-11-07T09:27:40Z',
#   'updated_at': '2023-11-07T10:36:23Z',
#   'pushed_at': '2023-11-13T01:06:25Z',
#   'git_url': 'git://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'ssh_url': 'git@github.com:caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'clone_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#   'svn_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis',
#   'homepage': None,
#   'size': 4810,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 814328439,
#   'node_id': 'R_kgDOMImqdw',
#   'name': 'udend-capstone-project',
#   'full_name': 'caiosm01/udend-capstone-project',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/udend-capstone-project',
#   'description': "My Capstone Project for Udacity's Nanodegree Program",
#   'fork': True,
#   'url': 'https://api.github.com/repos/caiosm01/udend-capstone-project',
#   'forks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/deployments',
#   'created_at': '2024-06-12T19:45:33Z',
#   'updated_at': '2024-06-12T19:45:33Z',
#   'pushed_at': '2021-08-03T02:43:43Z',
#   'git_url': 'git://github.com/caiosm01/udend-capstone-project.git',
#   'ssh_url': 'git@github.com:caiosm01/udend-capstone-project.git',
#   'clone_url': 'https://github.com/caiosm01/udend-capstone-project.git',
#   'svn_url': 'https://github.com/caiosm01/udend-capstone-project',
#   'homepage': None,
#   'size': 236260,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 817760189,
#   'node_id': 'R_kgDOML4HvQ',
#   'name': 'Web-Scraping---Google-Drive',
#   'full_name': 'caiosm01/Web-Scraping---Google-Drive',
#   'private': False,
#   'owner': {'login': 'caiosm01',
#    'id': 73209965,
#    'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caiosm01',
#    'html_url': 'https://github.com/caiosm01',
#    'followers_url': 'https://api.github.com/users/caiosm01/followers',
#    'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#    'repos_url': 'https://api.github.com/users/caiosm01/repos',
#    'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive',
#   'forks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/forks',
#   'keys_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/teams',
#   'hooks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/hooks',
#   'issue_events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/events',
#   'assignees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/tags',
#   'blobs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/languages',
#   'stargazers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/stargazers',
#   'contributors_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contributors',
#   'subscribers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscribers',
#   'subscription_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscription',
#   'commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/merges',
#   'archive_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/downloads',
#   'issues_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/deployments',
#   'created_at': '2024-06-20T11:38:09Z',
#   'updated_at': '2024-06-20T12:26:38Z',
#   'pushed_at': '2024-06-20T12:26:35Z',
#   'git_url': 'git://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#   'ssh_url': 'git@github.com:caiosm01/Web-Scraping---Google-Drive.git',
#   'clone_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#   'svn_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#   'homepage': None,
#   'size': 9,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]

# %%
len(response.json())
# Out:
# 15

# %% [markdown]
# ### Autenticação

# %%
import os
from dotenv import load_dotenv


#load_dotenv(override=True)
access_token = os.getenv("access_token")

# Especifincando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28',
           'Authorization': 'Bearer '+ access_token}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'caiosm01' # username de quem vamos extrair os dados
#owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
repos_list = []

for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 929971125,
#    'node_id': 'R_kgDON247tQ',
#    'name': 'Alura_pipeline_dados',
#    'full_name': 'caiosm01/Alura_pipeline_dados',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Alura_pipeline_dados/deployments',
#    'created_at': '2025-02-09T20:14:21Z',
#    'updated_at': '2025-02-09T20:19:29Z',
#    'pushed_at': '2025-02-09T20:18:57Z',
#    'git_url': 'git://github.com/caiosm01/Alura_pipeline_dados.git',
#    'ssh_url': 'git@github.com:caiosm01/Alura_pipeline_dados.git',
#    'clone_url': 'https://github.com/caiosm01/Alura_pipeline_dados.git',
#    'svn_url': 'https://github.com/caiosm01/Alura_pipeline_dados',
#    'homepage': None,
#    'size': 81953,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 930407851,
#    'node_id': 'R_kgDON3Tlqw',
#    'name': 'alura_projeto_requests',
#    'full_name': 'caiosm01/alura_projeto_requests',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/alura_projeto_requests',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests',
#    'forks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/alura_projeto_requests/deployments',
#    'created_at': '2025-02-10T15:32:18Z',
#    'updated_at': '2025-02-10T21:14:37Z',
#    'pushed_at': '2025-02-10T21:14:25Z',
#    'git_url': 'git://github.com/caiosm01/alura_projeto_requests.git',
#    'ssh_url': 'git@github.com:caiosm01/alura_projeto_requests.git',
#    'clone_url': 'https://github.com/caiosm01/alura_projeto_requests.git',
#    'svn_url': 'https://github.com/caiosm01/alura_projeto_requests',
#    'homepage': None,
#    'size': 65364,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 391142915,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTExNDI5MTU=',
#    'name': 'caiosm01',
#    'full_name': 'caiosm01/caiosm01',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/caiosm01',
#    'description': 'Config files for my GitHub profile.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/caiosm01',
#    'forks_url': 'https://api.github.com/repos/caiosm01/caiosm01/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/caiosm01/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm01/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/caiosm01/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm01/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/caiosm01/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm01/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/caiosm01/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm01/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/caiosm01/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm01/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm01/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm01/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm01/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/caiosm01/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/caiosm01/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/caiosm01/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/caiosm01/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/caiosm01/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm01/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/caiosm01/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm01/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm01/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm01/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/caiosm01/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/caiosm01/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm01/deployments',
#    'created_at': '2021-07-30T17:21:43Z',
#    'updated_at': '2023-09-22T17:50:17Z',
#    'pushed_at': '2023-09-22T19:45:58Z',
#    'git_url': 'git://github.com/caiosm01/caiosm01.git',
#    'ssh_url': 'git@github.com:caiosm01/caiosm01.git',
#    'clone_url': 'https://github.com/caiosm01/caiosm01.git',
#    'svn_url': 'https://github.com/caiosm01/caiosm01',
#    'homepage': 'https://github.com/caiosm01',
#    'size': 3,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['config', 'github-config'],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 774679982,
#    'node_id': 'R_kgDOLiytrg',
#    'name': 'caiosm1.github.io',
#    'full_name': 'caiosm01/caiosm1.github.io',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/caiosm1.github.io',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io',
#    'forks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/caiosm1.github.io/deployments',
#    'created_at': '2024-03-20T01:18:03Z',
#    'updated_at': '2024-11-14T12:03:16Z',
#    'pushed_at': '2024-11-14T12:03:12Z',
#    'git_url': 'git://github.com/caiosm01/caiosm1.github.io.git',
#    'ssh_url': 'git@github.com:caiosm01/caiosm1.github.io.git',
#    'clone_url': 'https://github.com/caiosm01/caiosm1.github.io.git',
#    'svn_url': 'https://github.com/caiosm01/caiosm1.github.io',
#    'homepage': None,
#    'size': 5160,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'unlicense',
#     'name': 'The Unlicense',
#     'spdx_id': 'Unlicense',
#     'url': 'https://api.github.com/licenses/unlicense',
#     'node_id': 'MDc6TGljZW5zZTE1'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 467736815,
#    'node_id': 'R_kgDOG-EY7w',
#    'name': 'CursoEmVideo_PythonExercicios',
#    'full_name': 'caiosm01/CursoEmVideo_PythonExercicios',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios',
#    'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_PythonExercicios/deployments',
#    'created_at': '2022-03-09T01:35:20Z',
#    'updated_at': '2022-03-09T01:56:27Z',
#    'pushed_at': '2022-03-09T01:56:20Z',
#    'git_url': 'git://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#    'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_PythonExercicios.git',
#    'clone_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios.git',
#    'svn_url': 'https://github.com/caiosm01/CursoEmVideo_PythonExercicios',
#    'homepage': None,
#    'size': 93881,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 467745215,
#    'node_id': 'R_kgDOG-E5vw',
#    'name': 'CursoEmVideo_WebDesign',
#    'full_name': 'caiosm01/CursoEmVideo_WebDesign',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign',
#    'forks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/CursoEmVideo_WebDesign/deployments',
#    'created_at': '2022-03-09T02:10:19Z',
#    'updated_at': '2022-03-09T02:11:16Z',
#    'pushed_at': '2022-03-09T02:11:12Z',
#    'git_url': 'git://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#    'ssh_url': 'git@github.com:caiosm01/CursoEmVideo_WebDesign.git',
#    'clone_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign.git',
#    'svn_url': 'https://github.com/caiosm01/CursoEmVideo_WebDesign',
#    'homepage': None,
#    'size': 5307,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 805422935,
#    'node_id': 'R_kgDOMAHHVw',
#    'name': 'Market_Basket_Analysis_Apriori',
#    'full_name': 'caiosm01/Market_Basket_Analysis_Apriori',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#    'description': 'Analisé de dados de uma cesta de mercado utilizando o algoritmo Apriori, com o objetivo de observar a correlação entre os produtos adquiridos pelos clientes',
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Market_Basket_Analysis_Apriori/deployments',
#    'created_at': '2024-05-24T14:38:51Z',
#    'updated_at': '2024-06-20T16:09:27Z',
#    'pushed_at': '2024-06-20T16:07:22Z',
#    'git_url': 'git://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#    'ssh_url': 'git@github.com:caiosm01/Market_Basket_Analysis_Apriori.git',
#    'clone_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori.git',
#    'svn_url': 'https://github.com/caiosm01/Market_Basket_Analysis_Apriori',
#    'homepage': None,
#    'size': 109,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 468989018,
#    'node_id': 'R_kgDOG_Q0Wg',
#    'name': 'projeto1_AnaliseDeDados_FreeCodeCamp',
#    'full_name': 'caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp',
#    'forks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/projeto1_AnaliseDeDados_FreeCodeCamp/labels{/name}',
# ...
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Transformacao_e_Encoding_de_Variaveis/deployments',
#    'created_at': '2023-11-07T09:27:40Z',
#    'updated_at': '2023-11-07T10:36:23Z',
#    'pushed_at': '2023-11-13T01:06:25Z',
#    'git_url': 'git://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'ssh_url': 'git@github.com:caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'clone_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis.git',
#    'svn_url': 'https://github.com/caiosm01/Transformacao_e_Encoding_de_Variaveis',
#    'homepage': None,
#    'size': 4810,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 814328439,
#    'node_id': 'R_kgDOMImqdw',
#    'name': 'udend-capstone-project',
#    'full_name': 'caiosm01/udend-capstone-project',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/udend-capstone-project',
#    'description': "My Capstone Project for Udacity's Nanodegree Program",
#    'fork': True,
#    'url': 'https://api.github.com/repos/caiosm01/udend-capstone-project',
#    'forks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/udend-capstone-project/deployments',
#    'created_at': '2024-06-12T19:45:33Z',
#    'updated_at': '2024-06-12T19:45:33Z',
#    'pushed_at': '2021-08-03T02:43:43Z',
#    'git_url': 'git://github.com/caiosm01/udend-capstone-project.git',
#    'ssh_url': 'git@github.com:caiosm01/udend-capstone-project.git',
#    'clone_url': 'https://github.com/caiosm01/udend-capstone-project.git',
#    'svn_url': 'https://github.com/caiosm01/udend-capstone-project',
#    'homepage': None,
#    'size': 236260,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}},
#   {'id': 817760189,
#    'node_id': 'R_kgDOML4HvQ',
#    'name': 'Web-Scraping---Google-Drive',
#    'full_name': 'caiosm01/Web-Scraping---Google-Drive',
#    'private': False,
#    'owner': {'login': 'caiosm01',
#     'id': 73209965,
#     'node_id': 'MDQ6VXNlcjczMjA5OTY1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/73209965?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/caiosm01',
#     'html_url': 'https://github.com/caiosm01',
#     'followers_url': 'https://api.github.com/users/caiosm01/followers',
#     'following_url': 'https://api.github.com/users/caiosm01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/caiosm01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/caiosm01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/caiosm01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/caiosm01/orgs',
#     'repos_url': 'https://api.github.com/users/caiosm01/repos',
#     'events_url': 'https://api.github.com/users/caiosm01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/caiosm01/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive',
#    'forks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/forks',
#    'keys_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/teams',
#    'hooks_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/hooks',
#    'issue_events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/events',
#    'assignees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/tags',
#    'blobs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/languages',
#    'stargazers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/stargazers',
#    'contributors_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contributors',
#    'subscribers_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscribers',
#    'subscription_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/subscription',
#    'commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/merges',
#    'archive_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/downloads',
#    'issues_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/caiosm01/Web-Scraping---Google-Drive/deployments',
#    'created_at': '2024-06-20T11:38:09Z',
#    'updated_at': '2024-06-20T12:26:38Z',
#    'pushed_at': '2024-06-20T12:26:35Z',
#    'git_url': 'git://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#    'ssh_url': 'git@github.com:caiosm01/Web-Scraping---Google-Drive.git',
#    'clone_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive.git',
#    'svn_url': 'https://github.com/caiosm01/Web-Scraping---Google-Drive',
#    'homepage': None,
#    'size': 9,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': True,
#     'maintain': True,
#     'push': True,
#     'triage': True,
#     'pull': True}}],
#  [],
#  [],
#  [],
#  []]

# %%
len(repos_list[0])
# Out:
# 15

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list[0][1]['name']
# Out:
# 'alura_projeto_requests'

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name
# Out:
# ['Alura_pipeline_dados',
#  'alura_projeto_requests',
#  'caiosm01',
#  'caiosm1.github.io',
#  'CursoEmVideo_PythonExercicios',
#  'CursoEmVideo_WebDesign',
#  'Market_Basket_Analysis_Apriori',
#  'projeto1_AnaliseDeDados_FreeCodeCamp',
#  'projeto1_Python_FreeCodeCamp',
#  'projeto2_AnaliseDeDados_FreeCodeCamp',
#  'projeto_engenharia_de_dados_pesquisas',
#  'teste',
#  'Transformacao_e_Encoding_de_Variaveis',
#  'udend-capstone-project',
#  'Web-Scraping---Google-Drive']

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[0][0]['language']
# Out:
# 'Python'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
repos_language
# Out:
# ['Python',
#  'Python',
#  None,
#  'HTML',
#  'Python',
#  'HTML',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  None,
#  'Python']

# %% [markdown]
# ## Criando um DataFrame

# %%
import pandas as pd

# %%
dados = pd.DataFrame()
dados['repository_name'] = repos_name
dados['language'] = repos_language

# %%
dados
# Out:
#                           repository_name          language
# 0                    Alura_pipeline_dados            Python
# 1                  alura_projeto_requests            Python
# 2                                caiosm01              None
# 3                       caiosm1.github.io              HTML
# 4           CursoEmVideo_PythonExercicios            Python
# 5                  CursoEmVideo_WebDesign              HTML
# 6          Market_Basket_Analysis_Apriori  Jupyter Notebook
# 7    projeto1_AnaliseDeDados_FreeCodeCamp            Python
# 8            projeto1_Python_FreeCodeCamp            Python
# 9    projeto2_AnaliseDeDados_FreeCodeCamp            Python
# 10  projeto_engenharia_de_dados_pesquisas            Python
# 11                                  teste              None
# 12  Transformacao_e_Encoding_de_Variaveis  Jupyter Notebook
# 13                 udend-capstone-project              None
# 14            Web-Scraping---Google-Drive            Python

# %%
print(dados.head())
# Out:
#                  repository_name language
# 0           Alura_pipeline_dados   Python
# 1         alura_projeto_requests   Python
# 2                       caiosm01     None
# 3              caiosm1.github.io     HTML
# 4  CursoEmVideo_PythonExercicios   Python

# %%
dados.to_csv('dados.csv', index=False)

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando reposítório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
#url = 'https://api.github.com/users/caiosm01/repos'
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da minha conta',
    'private': False
}

response = requests.post(url, json=data,headers=headers)
response.status_code
# Out:
# 422

# %% [markdown]
# ## Formato do arquivo

# %%
import base64

# %%
with open('dados.csv', 'rb') as file:
    file_content = file.read()

enconded_content = base64.b64encode(file_content)

# %% [markdown]
# ## Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'caiosm01'
repo = 'linguagens-utilizadas'
path = 'dados.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'

url
# Out:
# 'https://api.github.com/repos/caiosm01/linguagens-utilizadas/contents/dados.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': enconded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201
